# %%
# !ollama ls
# Out:
# NAME                    	ID          	SIZE  	MODIFIED
# llama3:8b               	365c0bd3c000	4.7 GB	About an hour ago
# llava:latest            	8dd30f6b0cb1	4.7 GB	40 hours ago
# llama3:8b-instruct-q5_1 	662158bc9277	6.1 GB	11 days ago
# mistral:latest          	2ae6f6dd7a3d	4.1 GB	12 days ago
# llama3-gradient:latest  	5d1398df5b8b	4.7 GB	2 weeks ago
# mxbai-embed-large:latest	468836162de7	669 MB	2 weeks ago
# llama3:latest           	365c0bd3c000	4.7 GB	2 weeks ago
# llama2:latest           	78e26419b446	3.8 GB	2 weeks ago
# phi3:3.8b               	64c1188f2485	2.4 GB	2 weeks ago

# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %%
from utilities.ollamaAdditionalFunctions import CustomOllamaFunctions, get_ollama_tools_system_message, get_ollama_custom_chatPrompt, create_ollama_functions_agent

# tools
from langchain_community.tools.tavily_search import TavilySearchResults
from langchain_community.tools import ArxivQueryRun, WikipediaQueryRun
from langchain_community.utilities import ArxivAPIWrapper, WikipediaAPIWrapper
from langchain_google_community import GoogleSearchAPIWrapper
from langchain_core.tools import Tool, StructuredTool, tool

# getting LLM
llm_ollama_func = CustomOllamaFunctions(model="llama3:8b", format="json")
# llm_ollama_func = CustomOllamaFunctions(model="mistral", format="json")

# create/get some tools
# tools = [TavilySearchResults(max_results=1), 
#          ArxivQueryRun(api_wrapper=ArxivAPIWrapper(top_k_results=1, doc_content_chars_max=500)), 
#          WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper(top_k_results=1, doc_content_chars_max=500))]

@tool
def google_search(query: str):
    """Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.

    Args:
        query (str): Query to search on Google.

    Returns:
        str: Google search results.
    """
    search = GoogleSearchAPIWrapper(k=1)
    return search.run(query)

tools = [google_search]

# getting system message
system_message = get_ollama_tools_system_message(tools)

# getting chat prompt
prompt = get_ollama_custom_chatPrompt()

# creating agent
agent = create_ollama_functions_agent(llm_ollama_func, prompt)
agent
# Out:
# functions: [{'name': 'google_search', 'parameters': {'title': 'google_searchSchema', 'description': 'Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\n\nArgs:\n    query (str): Query to search on Google.\n\nReturns:\n    str: Google search results.', 'type': 'object', 'properties': {'query': {'title': 'Query', 'type': 'string'}}, 'required': ['query']}, 'description': 'Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\n\n    Args:\n        query (str): Query to search on Google.\n\n    Returns:\n        str: Google search results.'}, {'name': 'conversational_response', 'description': 'Respond conversationally if no other tools should be called for a given query.', 'parameters': {'type': 'object', 'properties': {'response': {'type': 'string', 'description': 'Conversational response to the user.'}}, 'required': ['response']}}]
# sys mess: content='You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n'
# RunnableAssign(mapper={
#   agent_scratchpad: RunnableLambda(lambda x: format_to_ollama_tool_messages(x['intermediate_steps'], last_n_messages=last_n_messages))
# })
# | RunnableAssign(mapper={
#     print_input: RunnableLambda(lambda x: print(f'Agent Input - Inside agent chain: {x}'))
#   })
# | ChatPromptTemplate(input_variables=['agent_scratchpad', 'input', 'system_message'], optional_variables=['chat_history'], input_types={'chat_history': typing.List[typing.Union[langchain_core.messages.ai.AIMessage, langchain_core.messages.human.HumanMessage, langchain_core.messages.chat.ChatMessage, langchain_core.messages.system.SystemMessage, langchain_core.messages.function.FunctionMessage, langchain_core.messages.tool.ToolMessage]], 'agent_scratchpad': typing.List[typing.Union[langchain_core.messages.ai.AIMessage, langchain_core.messages.human.HumanMessage, langchain_core.messages.chat.ChatMessage, langchain_core.messages.system.SystemMessage, langchain_core.messages.function.FunctionMessage, langchain_core.messages.tool.ToolMessage]]}, partial_variables={'chat_history': []}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['system_message'], template='{system_message}')), MessagesPlaceholder(variable_name='chat_history', optional=True), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], template='{input}')), MessagesPlaceholder(variable_name='agent_scratchpad')])
# | RunnableLambda(fake_function)
# | CustomOllamaFunctions(model='llama3:8b', format='json')
# | OllamaAIFunctionsAgentOutputParser()

# %% [markdown]
# ### Langgraph components

# %% [markdown]
# #### StateGraph

# %%
import operator
from typing import Annotated, TypedDict, Union

from langchain_core.agents import AgentAction, AgentFinish
from langchain_core.messages import BaseMessage


class AgentState(TypedDict):
    # The input string
    input: str
    # System message
    system_message: str
    # The list of previous messages in the conversation
    chat_history: list[BaseMessage]
    # The outcome of a given call to the agent
    # Needs `None` as a valid type, since this is what this will start as
    agent_outcome: Union[AgentAction, AgentFinish, None]
    # List of actions and corresponding observations
    # Here we annotate this with `operator.add` to indicate that operations to
    # this state should be ADDED to the existing values (not overwrite it)
    intermediate_steps: Annotated[list[tuple[AgentAction, str]], operator.add]

# %% [markdown]
# #### Defining functions for Agent Graph to be built

# %%
from langchain_core.agents import AgentFinish
from langgraph.prebuilt.tool_executor import ToolExecutor

# This a helper class we have that is useful for running tools
# It takes in an agent action and calls that tool and returns the result
tool_executor = ToolExecutor(tools)

# Define the agent
def run_agent(data):
    print(f"keys in run agent: {data.keys()}")
    agent_outcome = agent.invoke(data)
    print("Agent Outcome: ", agent_outcome)
    return {"agent_outcome": agent_outcome}


# Define the function to execute tools
def execute_tools(data):
    print(f"keys in run tools: {data.keys()}, {len(data["intermediate_steps"])}")
    # Get the most recent agent_outcome - this is the key added in the `agent` above
    agent_action = data["agent_outcome"]
    output = tool_executor.invoke(agent_action)
    return {"intermediate_steps": [(agent_action, str(output))]}


# Define logic that will be used to determine which conditional edge to go down
def should_continue(data):
    print(f"keys in run continue: {data.keys()}, {len(data["intermediate_steps"])}")
    # If the agent outcome is an AgentFinish, then we return `exit` string
    # This will be used when setting up the graph to define the flow
    if isinstance(data["agent_outcome"], AgentFinish):
        return "end"
    # Otherwise, an AgentAction is returned
    # Here we return `continue` string
    # This will be used when setting up the graph to define the flow
    else:
        return "continue"

# %% [markdown]
# #### AgentGraph / LangGraph

# %%
from langgraph.graph import END, StateGraph

# Define a new graph
workflow = StateGraph(AgentState)

# Define the two nodes we will cycle between
workflow.add_node("agent", run_agent)
workflow.add_node("action", execute_tools)

# Set the entrypoint as `agent`
# This means that this node is the first one called
workflow.set_entry_point("agent")

# We now add a conditional edge
workflow.add_conditional_edges(
    # First, we define the start node. We use `agent`.
    # This means these are the edges taken after the `agent` node is called.
    "agent",
    # Next, we pass in the function that will determine which node is called next.
    should_continue,
    # Finally we pass in a mapping.
    # The keys are strings, and the values are other nodes.
    # END is a special node marking that the graph should finish.
    # What will happen is we will call `should_continue`, and then the output of that
    # will be matched against the keys in this mapping.
    # Based on which one it matches, that node will then be called.
    {
        # If `tools`, then we call the tool node.
        "continue": "action",
        # Otherwise we finish.
        "end": END,
    },
)

# We now add a normal edge from `tools` to `agent`.
# This means that after `tools` is called, `agent` node is called next.
workflow.add_edge("action", "agent")

# Finally, we compile it!
# This compiles it into a LangChain Runnable,
# meaning you can use it as you would any other runnable
app = workflow.compile()

# %% [markdown]
# #### Calling AgentGraph

# %%
# Ollama - Llama3:8b + Google Search
# inputs = {"input": "what is the weather in sf", "chat_history": [], "system_message": str(system_message.content)}
inputs = {"input": "what is machine learning in simple words?", "chat_history": [], "system_message": str(system_message.content)}
# inputs = {"input": "Find todays weather in san francisco?", "chat_history": [], "system_message": str(system_message.content)}
# inputs = {"input": "Who is the current Prime Minister of Australia?", "chat_history": [], "system_message": str(system_message.content)}
for s in app.stream(inputs):
    print(list(s.values())[0])
    print("----")
# Out:
# keys in run agent: dict_keys(['input', 'system_message', 'chat_history', 'agent_outcome', 'intermediate_steps'])
# Agent Input - Inside agent chain: {'input': 'what is machine learning in simple words?', 'system_message': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'chat_history': [], 'agent_outcome': None, 'intermediate_steps': [], 'agent_scratchpad': []}
# Fake function| Prompt: messages=[SystemMessage(content='You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n'), HumanMessage(content='what is machine learning in simple words?')]
# ENTERED CUSTOM OLLAMA FUNCTIONS GENERATE
# kwargs: {}
# Ollama messages: [{'role': 'system', 'content': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'images': []}, {'role': 'user', 'content': 'what is machine learning in simple words?', 'images': []}]
# final_chunk:  text='{ "tool": "google_search", "tool_input": { "query": "machine learning simple words" } }\n\n' generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T02:51:22.973641Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 14251937542, 'load_duration': 10665843084, 'prompt_eval_count': 376, 'prompt_eval_duration': 2213452000, 'eval_count': 25, 'eval_duration': 1365612000} message=AIMessageChunk(content='{ "tool": "google_search", "tool_input": { "query": "machine learning simple words" } }\n\n') Chunk text:  { "tool": "google_search", "tool_input": { "query": "machine learning simple words" } }
#
#
# EXECUTION DONE: generations=[ChatGeneration(text='{ "tool": "google_search", "tool_input": { "query": "machine learning simple words" } }\n\n', generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T02:51:22.973641Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 14251937542, 'load_duration': 10665843084, 'prompt_eval_count': 376, 'prompt_eval_duration': 2213452000, 'eval_count': 25, 'eval_duration': 1365612000}, message=AIMessage(content='{ "tool": "google_search", "tool_input": { "query": "machine learning simple words" } }\n\n'))] llm_output=None
# Response: Ollama:  {'tool': 'google_search', 'tool_input': {'query': 'machine learning simple words'}}
# response message with func: content='' tool_calls=[{'name': 'google_search', 'args': {'query': 'machine learning simple words'}, 'id': 'call_5c168e0851474d269c930e16cdf8ca84'}]
# Result from Ollm before extracting:  [ChatGeneration(message=AIMessage(content='', id='run-a4247c26-7def-41e2-8a11-06d99ba632c7-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'machine learning simple words'}, 'id': 'call_5c168e0851474d269c930e16cdf8ca84'}]))]
# Ollama func parse result:  content='' id='run-a4247c26-7def-41e2-8a11-06d99ba632c7-0' tool_calls=[{'name': 'google_search', 'args': {'query': 'machine learning simple words'}, 'id': 'call_5c168e0851474d269c930e16cdf8ca84'}]
# Tool Call:  {'name': 'google_search', 'args': {'query': 'machine learning simple words'}, 'id': 'call_5c168e0851474d269c930e16cdf8ca84'}
# Agent Outcome:  tool='google_search' tool_input={'query': 'machine learning simple words'} log="\nInvoking: `google_search` with `{'query': 'machine learning simple words'}`\n\n\n" message_log=[AIMessage(content='', id='run-a4247c26-7def-41e2-8a11-06d99ba632c7-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'machine learning simple words'}, 'id': 'call_5c168e0851474d269c930e16cdf8ca84'}])]
# keys in run continue: dict_keys(['agent_outcome', 'input', 'system_message', 'chat_history', 'intermediate_steps']), 0
# {'agent_outcome': AgentActionMessageLog(tool='google_search', tool_input={'query': 'machine learning simple words'}, log="\nInvoking: `google_search` with `{'query': 'machine learning simple words'}`\n\n\n", message_log=[AIMessage(content='', id='run-a4247c26-7def-41e2-8a11-06d99ba632c7-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'machine learning simple words'}, 'id': 'call_5c168e0851474d269c930e16cdf8ca84'}])])}
# ----
# keys in run tools: dict_keys(['input', 'system_message', 'chat_history', 'agent_outcome', 'intermediate_steps']), 0
# {'intermediate_steps': [(AgentActionMessageLog(tool='google_search', tool_input={'query': 'machine learning simple words'}, log="\nInvoking: `google_search` with `{'query': 'machine learning simple words'}`\n\n\n", message_log=[AIMessage(content='', id='run-a4247c26-7def-41e2-8a11-06d99ba632c7-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'machine learning simple words'}, 'id': 'call_5c168e0851474d269c930e16cdf8ca84'}])]), 'Machine learning (ML) is a branch of artificial intelligence (AI) and computer science that focuses on the using data and algorithms to enable AI to imitate the\xa0...')]}
# ----
# keys in run agent: dict_keys(['input', 'system_message', 'chat_history', 'agent_outcome', 'intermediate_steps'])
# Agent Action in create tool message func:  tool='google_search' tool_input={'query': 'machine learning simple words'} log="\nInvoking: `google_search` with `{'query': 'machine learning simple words'}`\n\n\n" message_log=[AIMessage(content='', id='run-a4247c26-7def-41e2-8a11-06d99ba632c7-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'machine learning simple words'}, 'id': 'call_5c168e0851474d269c930e16cdf8ca84'}])]
# Agent Input - Inside agent chain: {'input': 'what is machine learning in simple words?', 'system_message': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'chat_history': [], 'agent_outcome': AgentActionMessageLog(tool='google_search', tool_input={'query': 'machine learning simple words'}, log="\nInvoking: `google_search` with `{'query': 'machine learning simple words'}`\n\n\n", message_log=[AIMessage(content='', id='run-a4247c26-7def-41e2-8a11-06d99ba632c7-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'machine learning simple words'}, 'id': 'call_5c168e0851474d269c930e16cdf8ca84'}])]), 'intermediate_steps': [(AgentActionMessageLog(tool='google_search', tool_input={'query': 'machine learning simple words'}, log="\nInvoking: `google_search` with `{'query': 'machine learning simple words'}`\n\n\n", message_log=[AIMessage(content='', id='run-a4247c26-7def-41e2-8a11-06d99ba632c7-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'machine learning simple words'}, 'id': 'call_5c168e0851474d269c930e16cdf8ca84'}])]), 'Machine learning (ML) is a branch of artificial intelligence (AI) and computer science that focuses on the using data and algorithms to enable AI to imitate the\xa0...')], 'agent_scratchpad': [AIMessage(content='', id='run-a4247c26-7def-41e2-8a11-06d99ba632c7-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'machine learning simple words'}, 'id': 'call_5c168e0851474d269c930e16cdf8ca84'}]), ToolMessage(content='Machine learning (ML) is a branch of artificial intelligence (AI) and computer science that focuses on the using data and algorithms to enable AI to imitate the\xa0...', name='google_search', tool_call_id='call_5c168e0851474d269c930e16cdf8ca84')]}
# Fake function| Prompt: messages=[SystemMessage(content='You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n'), HumanMessage(content='what is machine learning in simple words?'), AIMessage(content='', id='run-a4247c26-7def-41e2-8a11-06d99ba632c7-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'machine learning simple words'}, 'id': 'call_5c168e0851474d269c930e16cdf8ca84'}]), ToolMessage(content='Machine learning (ML) is a branch of artificial intelligence (AI) and computer science that focuses on the using data and algorithms to enable AI to imitate the\xa0...', name='google_search', tool_call_id='call_5c168e0851474d269c930e16cdf8ca84')]
# ENTERED CUSTOM OLLAMA FUNCTIONS GENERATE
# kwargs: {}
# Ollama messages: [{'role': 'system', 'content': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'images': []}, {'role': 'user', 'content': 'what is machine learning in simple words?', 'images': []}, {'role': 'assistant', 'content': '', 'images': []}, {'role': 'user', 'content': 'Analyse this response taken from External tool google_search to answer my query: Machine learning (ML) is a branch of artificial intelligence (AI) and computer science that focuses on the using data and algorithms to enable AI to imitate the\xa0...', 'images': []}]
# final_chunk:  text='{"tool": "google_search", "tool_input": {"query": "Machine learning in simple words"}}' generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T02:51:25.605585Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 1656230583, 'load_duration': 6695125, 'prompt_eval_count': 59, 'prompt_eval_duration': 413084000, 'eval_count': 22, 'eval_duration': 1229076000} message=AIMessageChunk(content='{"tool": "google_search", "tool_input": {"query": "Machine learning in simple words"}}') Chunk text:  {"tool": "google_search", "tool_input": {"query": "Machine learning in simple words"}}
# EXECUTION DONE: generations=[ChatGeneration(text='{"tool": "google_search", "tool_input": {"query": "Machine learning in simple words"}}', generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T02:51:25.605585Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 1656230583, 'load_duration': 6695125, 'prompt_eval_count': 59, 'prompt_eval_duration': 413084000, 'eval_count': 22, 'eval_duration': 1229076000}, message=AIMessage(content='{"tool": "google_search", "tool_input": {"query": "Machine learning in simple words"}}'))] llm_output=None
# Response: Ollama:  {'tool': 'google_search', 'tool_input': {'query': 'Machine learning in simple words'}}
# response message with func: content='' tool_calls=[{'name': 'google_search', 'args': {'query': 'Machine learning in simple words'}, 'id': 'call_7fa81a12f6be4109923b524b31e4ee73'}]
# Result from Ollm before extracting:  [ChatGeneration(message=AIMessage(content='', id='run-84c35ae9-c85a-43b9-86df-59237c6f68d8-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Machine learning in simple words'}, 'id': 'call_7fa81a12f6be4109923b524b31e4ee73'}]))]
# Ollama func parse result:  content='' id='run-84c35ae9-c85a-43b9-86df-59237c6f68d8-0' tool_calls=[{'name': 'google_search', 'args': {'query': 'Machine learning in simple words'}, 'id': 'call_7fa81a12f6be4109923b524b31e4ee73'}]
# Tool Call:  {'name': 'google_search', 'args': {'query': 'Machine learning in simple words'}, 'id': 'call_7fa81a12f6be4109923b524b31e4ee73'}
# Agent Outcome:  tool='google_search' tool_input={'query': 'Machine learning in simple words'} log="\nInvoking: `google_search` with `{'query': 'Machine learning in simple words'}`\n\n\n" message_log=[AIMessage(content='', id='run-84c35ae9-c85a-43b9-86df-59237c6f68d8-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Machine learning in simple words'}, 'id': 'call_7fa81a12f6be4109923b524b31e4ee73'}])]
# keys in run continue: dict_keys(['agent_outcome', 'input', 'system_message', 'chat_history', 'intermediate_steps']), 1
# {'agent_outcome': AgentActionMessageLog(tool='google_search', tool_input={'query': 'Machine learning in simple words'}, log="\nInvoking: `google_search` with `{'query': 'Machine learning in simple words'}`\n\n\n", message_log=[AIMessage(content='', id='run-84c35ae9-c85a-43b9-86df-59237c6f68d8-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Machine learning in simple words'}, 'id': 'call_7fa81a12f6be4109923b524b31e4ee73'}])])}
# ----
# keys in run tools: dict_keys(['input', 'system_message', 'chat_history', 'agent_outcome', 'intermediate_steps']), 1
# {'intermediate_steps': [(AgentActionMessageLog(tool='google_search', tool_input={'query': 'Machine learning in simple words'}, log="\nInvoking: `google_search` with `{'query': 'Machine learning in simple words'}`\n\n\n", message_log=[AIMessage(content='', id='run-84c35ae9-c85a-43b9-86df-59237c6f68d8-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Machine learning in simple words'}, 'id': 'call_7fa81a12f6be4109923b524b31e4ee73'}])]), 'Machine learning (ML) is a branch of artificial intelligence (AI) and computer science that focuses on the using data and algorithms to enable AI to imitate the\xa0...')]}
# ----
# keys in run agent: dict_keys(['input', 'system_message', 'chat_history', 'agent_outcome', 'intermediate_steps'])
# Agent Action in create tool message func:  tool='google_search' tool_input={'query': 'machine learning simple words'} log="\nInvoking: `google_search` with `{'query': 'machine learning simple words'}`\n\n\n" message_log=[AIMessage(content='', id='run-a4247c26-7def-41e2-8a11-06d99ba632c7-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'machine learning simple words'}, 'id': 'call_5c168e0851474d269c930e16cdf8ca84'}])]
# Agent Action in create tool message func:  tool='google_search' tool_input={'query': 'Machine learning in simple words'} log="\nInvoking: `google_search` with `{'query': 'Machine learning in simple words'}`\n\n\n" message_log=[AIMessage(content='', id='run-84c35ae9-c85a-43b9-86df-59237c6f68d8-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Machine learning in simple words'}, 'id': 'call_7fa81a12f6be4109923b524b31e4ee73'}])]
# Agent Input - Inside agent chain: {'input': 'what is machine learning in simple words?', 'system_message': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'chat_history': [], 'agent_outcome': AgentActionMessageLog(tool='google_search', tool_input={'query': 'Machine learning in simple words'}, log="\nInvoking: `google_search` with `{'query': 'Machine learning in simple words'}`\n\n\n", message_log=[AIMessage(content='', id='run-84c35ae9-c85a-43b9-86df-59237c6f68d8-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Machine learning in simple words'}, 'id': 'call_7fa81a12f6be4109923b524b31e4ee73'}])]), 'intermediate_steps': [(AgentActionMessageLog(tool='google_search', tool_input={'query': 'machine learning simple words'}, log="\nInvoking: `google_search` with `{'query': 'machine learning simple words'}`\n\n\n", message_log=[AIMessage(content='', id='run-a4247c26-7def-41e2-8a11-06d99ba632c7-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'machine learning simple words'}, 'id': 'call_5c168e0851474d269c930e16cdf8ca84'}])]), 'Machine learning (ML) is a branch of artificial intelligence (AI) and computer science that focuses on the using data and algorithms to enable AI to imitate the\xa0...'), (AgentActionMessageLog(tool='google_search', tool_input={'query': 'Machine learning in simple words'}, log="\nInvoking: `google_search` with `{'query': 'Machine learning in simple words'}`\n\n\n", message_log=[AIMessage(content='', id='run-84c35ae9-c85a-43b9-86df-59237c6f68d8-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Machine learning in simple words'}, 'id': 'call_7fa81a12f6be4109923b524b31e4ee73'}])]), 'Machine learning (ML) is a branch of artificial intelligence (AI) and computer science that focuses on the using data and algorithms to enable AI to imitate the\xa0...')], 'agent_scratchpad': [AIMessage(content='', id='run-a4247c26-7def-41e2-8a11-06d99ba632c7-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'machine learning simple words'}, 'id': 'call_5c168e0851474d269c930e16cdf8ca84'}]), ToolMessage(content='Machine learning (ML) is a branch of artificial intelligence (AI) and computer science that focuses on the using data and algorithms to enable AI to imitate the\xa0...', name='google_search', tool_call_id='call_5c168e0851474d269c930e16cdf8ca84'), AIMessage(content='', id='run-84c35ae9-c85a-43b9-86df-59237c6f68d8-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Machine  ...
# Fake function| Prompt: messages=[SystemMessage(content='You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n'), HumanMessage(content='what is machine learning in simple words?'), AIMessage(content='', id='run-a4247c26-7def-41e2-8a11-06d99ba632c7-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'machine learning simple words'}, 'id': 'call_5c168e0851474d269c930e16cdf8ca84'}]), ToolMessage(content='Machine learning (ML) is a branch of artificial intelligence (AI) and computer science that focuses on the using data and algorithms to enable AI to imitate the\xa0...', name='google_search', tool_call_id='call_5c168e0851474d269c930e16cdf8ca84'), AIMessage(content='', id='run-84c35ae9-c85a-43b9-86df-59237c6f68d8-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Machine learning in simple words'}, 'id': 'call_7fa81a12f6be4109923b524b31e4ee73'}]), ToolMessage(content='Machine learning (ML) is a branch of artificial intelligence (AI) and computer science that focuses on the using data and algorithms to enable AI to imitate the\xa0...', name='google_search', tool_call_id='call_7fa81a12f6be4109923b524b31e4ee73')]
# ENTERED CUSTOM OLLAMA FUNCTIONS GENERATE
# kwargs: {}
# Ollama messages: [{'role': 'system', 'content': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'images': []}, {'role': 'user', 'content': 'what is machine learning in simple words?', 'images': []}, {'role': 'assistant', 'content': '', 'images': []}, {'role': 'user', 'content': 'Analyse this response taken from External tool google_search to answer my query: Machine learning (ML) is a branch of artificial intelligence (AI) and computer science that focuses on the using data and algorithms to enable AI to imitate the\xa0...', 'images': []}, {'role': 'assistant', 'content': '', 'images': []}, {'role': 'user', 'content': 'Analyse this response taken from External tool google_search to answer my query: Machine learning (ML) is a branch of artificial intelligence (AI) and computer science that focuses on the using data and algorithms to enable AI to imitate the\xa0...', 'images': []}]
# final_chunk:  text='{\n  "tool": "google_search",\n  "tool_input": {\n    "query": "what is machine learning in simple words"\n  }\n}' generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T02:51:28.482675Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 2288758291, 'load_duration': 3156541, 'prompt_eval_count': 59, 'prompt_eval_duration': 420879000, 'eval_count': 32, 'eval_duration': 1857101000} message=AIMessageChunk(content='{\n  "tool": "google_search",\n  "tool_input": {\n    "query": "what is machine learning in simple words"\n  }\n}') Chunk text:  {
#   "tool": "google_search",
#   "tool_input": {
#     "query": "what is machine learning in simple words"
#   }
# }
# EXECUTION DONE: generations=[ChatGeneration(text='{\n  "tool": "google_search",\n  "tool_input": {\n    "query": "what is machine learning in simple words"\n  }\n}', generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T02:51:28.482675Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 2288758291, 'load_duration': 3156541, 'prompt_eval_count': 59, 'prompt_eval_duration': 420879000, 'eval_count': 32, 'eval_duration': 1857101000}, message=AIMessage(content='{\n  "tool": "google_search",\n  "tool_input": {\n    "query": "what is machine learning in simple words"\n  }\n}'))] llm_output=None
# Response: Ollama:  {'tool': 'google_search', 'tool_input': {'query': 'what is machine learning in simple words'}}
# response message with func: content='' tool_calls=[{'name': 'google_search', 'args': {'query': 'what is machine learning in simple words'}, 'id': 'call_7443cc9328c64e42a884574d7d7ae8e7'}]
# Result from Ollm before extracting:  [ChatGeneration(message=AIMessage(content='', id='run-b2095fdc-9888-4043-a96d-5cc7960cca05-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'what is machine learning in simple words'}, 'id': 'call_7443cc9328c64e42a884574d7d7ae8e7'}]))]
# Ollama func parse result:  content='' id='run-b2095fdc-9888-4043-a96d-5cc7960cca05-0' tool_calls=[{'name': 'google_search', 'args': {'query': 'what is machine learning in simple words'}, 'id': 'call_7443cc9328c64e42a884574d7d7ae8e7'}]
# Tool Call:  {'name': 'google_search', 'args': {'query': 'what is machine learning in simple words'}, 'id': 'call_7443cc9328c64e42a884574d7d7ae8e7'}
# Agent Outcome:  tool='google_search' tool_input={'query': 'what is machine learning in simple words'} log="\nInvoking: `google_search` with `{'query': 'what is machine learning in simple words'}`\n\n\n" message_log=[AIMessage(content='', id='run-b2095fdc-9888-4043-a96d-5cc7960cca05-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'what is machine learning in simple words'}, 'id': 'call_7443cc9328c64e42a884574d7d7ae8e7'}])]
# keys in run continue: dict_keys(['agent_outcome', 'input', 'system_message', 'chat_history', 'intermediate_steps']), 2
# {'agent_outcome': AgentActionMessageLog(tool='google_search', tool_input={'query': 'what is machine learning in simple words'}, log="\nInvoking: `google_search` with `{'query': 'what is machine learning in simple words'}`\n\n\n", message_log=[AIMessage(content='', id='run-b2095fdc-9888-4043-a96d-5cc7960cca05-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'what is machine learning in simple words'}, 'id': 'call_7443cc9328c64e42a884574d7d7ae8e7'}])])}
# ----
# keys in run tools: dict_keys(['input', 'system_message', 'chat_history', 'agent_outcome', 'intermediate_steps']), 2
# {'intermediate_steps': [(AgentActionMessageLog(tool='google_search', tool_input={'query': 'what is machine learning in simple words'}, log="\nInvoking: `google_search` with `{'query': 'what is machine learning in simple words'}`\n\n\n", message_log=[AIMessage(content='', id='run-b2095fdc-9888-4043-a96d-5cc7960cca05-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'what is machine learning in simple words'}, 'id': 'call_7443cc9328c64e42a884574d7d7ae8e7'}])]), 'Machine learning (ML) is a branch of artificial intelligence (AI) and computer science that focuses on the using data and algorithms to enable AI to imitate the\xa0...')]}
# ----
# keys in run agent: dict_keys(['input', 'system_message', 'chat_history', 'agent_outcome', 'intermediate_steps'])
# Agent Action in create tool message func:  tool='google_search' tool_input={'query': 'machine learning simple words'} log="\nInvoking: `google_search` with `{'query': 'machine learning simple words'}`\n\n\n" message_log=[AIMessage(content='', id='run-a4247c26-7def-41e2-8a11-06d99ba632c7-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'machine learning simple words'}, 'id': 'call_5c168e0851474d269c930e16cdf8ca84'}])]
# Agent Action in create tool message func:  tool='google_search' tool_input={'query': 'Machine learning in simple words'} log="\nInvoking: `google_search` with `{'query': 'Machine learning in simple words'}`\n\n\n" message_log=[AIMessage(content='', id='run-84c35ae9-c85a-43b9-86df-59237c6f68d8-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Machine learning in simple words'}, 'id': 'call_7fa81a12f6be4109923b524b31e4ee73'}])]
# Agent Action in create tool message func:  tool='google_search' tool_input={'query': 'what is machine learning in simple words'} log="\nInvoking: `google_search` with `{'query': 'what is machine learning in simple words'}`\n\n\n" message_log=[AIMessage(content='', id='run-b2095fdc-9888-4043-a96d-5cc7960cca05-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'what is machine learning in simple words'}, 'id': 'call_7443cc9328c64e42a884574d7d7ae8e7'}])]
# Agent Input - Inside agent chain: {'input': 'what is machine learning in simple words?', 'system_message': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'chat_history': [], 'agent_outcome': AgentActionMessageLog(tool='google_search', tool_input={'query': 'what is machine learning in simple words'}, log="\nInvoking: `google_search` with `{'query': 'what is machine learning in simple words'}`\n\n\n", message_log=[AIMessage(content='', id='run-b2095fdc-9888-4043-a96d-5cc7960cca05-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'what is machine learning in simple words'}, 'id': 'call_7443cc9328c64e42a884574d7d7ae8e7'}])]), 'intermediate_steps': [(AgentActionMessageLog(tool='google_search', tool_input={'query': 'machine learning simple words'}, log="\nInvoking: `google_search` with `{'query': 'machine learning simple words'}`\n\n\n", message_log=[AIMessage(content='', id='run-a4247c26-7def-41e2-8a11-06d99ba632c7-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'machine learning simple words'}, 'id': 'call_5c168e0851474d269c930e16cdf8ca84'}])]), 'Machine learning (ML) is a branch of artificial intelligence (AI) and computer science that focuses on the using data and algorithms to enable AI to imitate the\xa0...'), (AgentActionMessageLog(tool='google_search', tool_input={'query': 'Machine learning in simple words'}, log="\nInvoking: `google_search` with `{'query': 'Machine learning in simple words'}`\n\n\n", message_log=[AIMessage(content='', id='run-84c35ae9-c85a-43b9-86df-59237c6f68d8-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Machine learning in simple words'}, 'id': 'call_7fa81a12f6be4109923b524b31e4ee73'}])]), 'Machine learning (ML) is a branch of artificial intelligence (AI) and computer science that focuses on the using data and algorithms to enable AI to imitate the\xa0...'), (AgentActionMessageLog(tool='google_search', tool_input={'query': 'what is machine learning in simple words'}, log="\nInvoking: `google_search` with `{'query': 'what is machine learning in simple words'}`\n\n\n", message_log=[AIMessage(content='', id='run-b2095fdc-9888-4043-a96d-5cc7960cca05-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'what is machine learning in simple words'}, 'id': 'call_7443cc9328c64e42a884574d7d7ae8e7'}])]), 'Machine learning (ML) is a branch of artificial intelligence (AI) and computer science that focuses on the using data and algorithms to enable AI to imitate the\x ...
# Fake function| Prompt: messages=[SystemMessage(content='You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n'), HumanMessage(content='what is machine learning in simple words?'), AIMessage(content='', id='run-a4247c26-7def-41e2-8a11-06d99ba632c7-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'machine learning simple words'}, 'id': 'call_5c168e0851474d269c930e16cdf8ca84'}]), ToolMessage(content='Machine learning (ML) is a branch of artificial intelligence (AI) and computer science that focuses on the using data and algorithms to enable AI to imitate the\xa0...', name='google_search', tool_call_id='call_5c168e0851474d269c930e16cdf8ca84'), AIMessage(content='', id='run-84c35ae9-c85a-43b9-86df-59237c6f68d8-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Machine learning in simple words'}, 'id': 'call_7fa81a12f6be4109923b524b31e4ee73'}]), ToolMessage(content='Machine learning (ML) is a branch of artificial intelligence (AI) and computer science that focuses on the using data and algorithms to enable AI to imitate the\xa0...', name='google_search', tool_call_id='call_7fa81a12f6be4109923b524b31e4ee73'), AIMessage(content='', id='run-b2095fdc-9888-4043-a96d-5cc7960cca05-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'what is machine learning in simple words'}, 'id': 'call_7443cc9328c64e42a884574d7d7ae8e7'}]), ToolMessage(content='Machine learning (ML) is a branch of artificial intelligence (AI) and computer science that focuses on the using data and algorithms to enable AI to imitate the\xa0...', name='google_search', tool_call_id='call_7443cc9328c64e42a884574d7d7ae8e7')]
# ENTERED CUSTOM OLLAMA FUNCTIONS GENERATE
# kwargs: {}
# Ollama messages: [{'role': 'system', 'content': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'images': []}, {'role': 'user', 'content': 'what is machine learning in simple words?', 'images': []}, {'role': 'assistant', 'content': '', 'images': []}, {'role': 'user', 'content': 'Analyse this response taken from External tool google_search to answer my query: Machine learning (ML) is a branch of artificial intelligence (AI) and computer science that focuses on the using data and algorithms to enable AI to imitate the\xa0...', 'images': []}, {'role': 'assistant', 'content': '', 'images': []}, {'role': 'user', 'content': 'Analyse this response taken from External tool google_search to answer my query: Machine learning (ML) is a branch of artificial intelligence (AI) and computer science that focuses on the using data and algorithms to enable AI to imitate the\xa0...', 'images': []}, {'role': 'assistant', 'content': '', 'images': []}, {'role': 'user', 'content': 'Analyse this response taken from External tool google_search to answer my query: Machine learning (ML) is a branch of artificial intelligence (AI) and computer science that focuses on the using data and algorithms to enable AI to imitate the\xa0...', 'images': []}]
# final_chunk:  text='{\n  "tool": "conversational_response",\n  "tool_input": {\n    "response": "Machine learning, in simple words, is when computers learn from data without being explicitly programmed. They use this learned information to make predictions or decisions, just like humans do."\n  }\n}' generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T02:51:32.953559Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 3897179542, 'load_duration': 1686417, 'prompt_eval_count': 59, 'prompt_eval_duration': 418878000, 'eval_count': 60, 'eval_duration': 3469060000} message=AIMessageChunk(content='{\n  "tool": "conversational_response",\n  "tool_input": {\n    "response": "Machine learning, in simple words, is when computers learn from data without being explicitly programmed. They use this learned information to make predictions or decisions, just like humans do."\n  }\n}') Chunk text:  {
#   "tool": "conversational_response",
#   "tool_input": {
#     "response": "Machine learning, in simple words, is when computers learn from data without being explicitly programmed. They use this learned information to make predictions or decisions, just like humans do."
#   }
# }
# EXECUTION DONE: generations=[ChatGeneration(text='{\n  "tool": "conversational_response",\n  "tool_input": {\n    "response": "Machine learning, in simple words, is when computers learn from data without being explicitly programmed. They use this learned information to make predictions or decisions, just like humans do."\n  }\n}', generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T02:51:32.953559Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 3897179542, 'load_duration': 1686417, 'prompt_eval_count': 59, 'prompt_eval_duration': 418878000, 'eval_count': 60, 'eval_duration': 3469060000}, message=AIMessage(content='{\n  "tool": "conversational_response",\n  "tool_input": {\n    "response": "Machine learning, in simple words, is when computers learn from data without being explicitly programmed. They use this learned information to make predictions or decisions, just like humans do."\n  }\n}'))] llm_output=None
# Response: Ollama:  {'tool': 'conversational_response', 'tool_input': {'response': 'Machine learning, in simple words, is when computers learn from data without being explicitly programmed. They use this learned information to make predictions or decisions, just like humans do.'}}
# Result from Ollm before extracting:  [ChatGeneration(text='Machine learning, in simple words, is when computers learn from data without being explicitly programmed. They use this learned information to make predictions or decisions, just like humans do.', message=AIMessage(content='Machine learning, in simple words, is when computers learn from data without being explicitly programmed. They use this learned information to make predictions or decisions, just like humans do.', id='run-289af66f-be0d-4284-bd92-2e3a16a7cd06-0'))]
# Ollama func parse result:  content='Machine learning, in simple words, is when computers learn from data without being explicitly programmed. They use this learned information to make predictions or decisions, just like humans do.' id='run-289af66f-be0d-4284-bd92-2e3a16a7cd06-0'
# Agent Outcome:  return_values={'output': 'Machine learning, in simple words, is when computers learn from data without being explicitly programmed. They use this learned information to make predictions or decisions, just like humans do.'} log="content='Machine learning, in simple words, is when computers learn from data without being explicitly programmed. They use this learned information to make predictions or decisions, just like humans do.' id='run-289af66f-be0d-4284-bd92-2e3a16a7cd06-0'"
# keys in run continue: dict_keys(['agent_outcome', 'input', 'system_message', 'chat_history', 'intermediate_steps']), 3
# {'agent_outcome': AgentFinish(return_values={'output': 'Machine learning, in simple words, is when computers learn from data without being explicitly programmed. They use this learned information to make predictions or decisions, just like humans do.'}, log="content='Machine learning, in simple words, is when computers learn from data without being explicitly programmed. They use this learned information to make predictions or decisions, just like humans do.' id='run-289af66f-be0d-4284-bd92-2e3a16a7cd06-0'")}
# ----

# %%
# Ollama - Llama3:8b + Google Search
# inputs = {"input": "what is the weather in sf", "chat_history": [], "system_message": str(system_message.content)}
# inputs = {"input": "what is machine learning in simple words?", "chat_history": [], "system_message": str(system_message.content)}
inputs = {"input": "Find todays weather in san francisco?", "chat_history": [], "system_message": str(system_message.content)}
# inputs = {"input": "Who is the current Prime Minister of Australia?", "chat_history": [], "system_message": str(system_message.content)}
for s in app.stream(inputs):
    print(list(s.values())[0])
    print("----")
# Out:
# keys in run agent: dict_keys(['input', 'system_message', 'chat_history', 'agent_outcome', 'intermediate_steps'])
# Agent Input - Inside agent chain: {'input': 'Find todays weather in san francisco?', 'system_message': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'chat_history': [], 'agent_outcome': None, 'intermediate_steps': [], 'agent_scratchpad': []}
# Fake function| Prompt: messages=[SystemMessage(content='You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n'), HumanMessage(content='Find todays weather in san francisco?')]
# ENTERED CUSTOM OLLAMA FUNCTIONS GENERATE
# kwargs: {}
# Ollama messages: [{'role': 'system', 'content': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'images': []}, {'role': 'user', 'content': 'Find todays weather in san francisco?', 'images': []}]
# final_chunk:  text='{"tool": "google_search", \n"tool_input": {"query": "weather in San Francisco today"}}' generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T02:42:50.841038Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 16214634000, 'load_duration': 8094500, 'prompt_eval_count': 14, 'prompt_eval_duration': 10065057000, 'eval_count': 23, 'eval_duration': 6132028000} message=AIMessageChunk(content='{"tool": "google_search", \n"tool_input": {"query": "weather in San Francisco today"}}') Chunk text:  {"tool": "google_search",
# "tool_input": {"query": "weather in San Francisco today"}}
# EXECUTION DONE: generations=[ChatGeneration(text='{"tool": "google_search", \n"tool_input": {"query": "weather in San Francisco today"}}', generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T02:42:50.841038Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 16214634000, 'load_duration': 8094500, 'prompt_eval_count': 14, 'prompt_eval_duration': 10065057000, 'eval_count': 23, 'eval_duration': 6132028000}, message=AIMessage(content='{"tool": "google_search", \n"tool_input": {"query": "weather in San Francisco today"}}'))] llm_output=None
# Response: Ollama:  {'tool': 'google_search', 'tool_input': {'query': 'weather in San Francisco today'}}
# response message with func: content='' tool_calls=[{'name': 'google_search', 'args': {'query': 'weather in San Francisco today'}, 'id': 'call_78771907f6674782af4f5044e957ac02'}]
# Result from Ollm before extracting:  [ChatGeneration(message=AIMessage(content='', id='run-3bed1068-87ca-4c71-950a-96cea2fc0587-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'weather in San Francisco today'}, 'id': 'call_78771907f6674782af4f5044e957ac02'}]))]
# Ollama func parse result:  content='' id='run-3bed1068-87ca-4c71-950a-96cea2fc0587-0' tool_calls=[{'name': 'google_search', 'args': {'query': 'weather in San Francisco today'}, 'id': 'call_78771907f6674782af4f5044e957ac02'}]
# Tool Call:  {'name': 'google_search', 'args': {'query': 'weather in San Francisco today'}, 'id': 'call_78771907f6674782af4f5044e957ac02'}
# Agent Outcome:  tool='google_search' tool_input={'query': 'weather in San Francisco today'} log="\nInvoking: `google_search` with `{'query': 'weather in San Francisco today'}`\n\n\n" message_log=[AIMessage(content='', id='run-3bed1068-87ca-4c71-950a-96cea2fc0587-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'weather in San Francisco today'}, 'id': 'call_78771907f6674782af4f5044e957ac02'}])]
# keys in run continue: dict_keys(['agent_outcome', 'input', 'system_message', 'chat_history', 'intermediate_steps']), 0
# {'agent_outcome': AgentActionMessageLog(tool='google_search', tool_input={'query': 'weather in San Francisco today'}, log="\nInvoking: `google_search` with `{'query': 'weather in San Francisco today'}`\n\n\n", message_log=[AIMessage(content='', id='run-3bed1068-87ca-4c71-950a-96cea2fc0587-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'weather in San Francisco today'}, 'id': 'call_78771907f6674782af4f5044e957ac02'}])])}
# ----
# keys in run tools: dict_keys(['input', 'system_message', 'chat_history', 'agent_outcome', 'intermediate_steps']), 0
# {'intermediate_steps': [(AgentActionMessageLog(tool='google_search', tool_input={'query': 'weather in San Francisco today'}, log="\nInvoking: `google_search` with `{'query': 'weather in San Francisco today'}`\n\n\n", message_log=[AIMessage(content='', id='run-3bed1068-87ca-4c71-950a-96cea2fc0587-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'weather in San Francisco today'}, 'id': 'call_78771907f6674782af4f5044e957ac02'}])]), 'Weather Today in San Francisco, CA ; High / Low. 67°/54° ; Wind. 15 mph ; Humidity. 74% ; Dew Point. 58° ; Pressure. 29.90 in.')]}
# ----
# keys in run agent: dict_keys(['input', 'system_message', 'chat_history', 'agent_outcome', 'intermediate_steps'])
# Agent Action in create tool message func:  tool='google_search' tool_input={'query': 'weather in San Francisco today'} log="\nInvoking: `google_search` with `{'query': 'weather in San Francisco today'}`\n\n\n" message_log=[AIMessage(content='', id='run-3bed1068-87ca-4c71-950a-96cea2fc0587-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'weather in San Francisco today'}, 'id': 'call_78771907f6674782af4f5044e957ac02'}])]
# Agent Input - Inside agent chain: {'input': 'Find todays weather in san francisco?', 'system_message': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'chat_history': [], 'agent_outcome': AgentActionMessageLog(tool='google_search', tool_input={'query': 'weather in San Francisco today'}, log="\nInvoking: `google_search` with `{'query': 'weather in San Francisco today'}`\n\n\n", message_log=[AIMessage(content='', id='run-3bed1068-87ca-4c71-950a-96cea2fc0587-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'weather in San Francisco today'}, 'id': 'call_78771907f6674782af4f5044e957ac02'}])]), 'intermediate_steps': [(AgentActionMessageLog(tool='google_search', tool_input={'query': 'weather in San Francisco today'}, log="\nInvoking: `google_search` with `{'query': 'weather in San Francisco today'}`\n\n\n", message_log=[AIMessage(content='', id='run-3bed1068-87ca-4c71-950a-96cea2fc0587-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'weather in San Francisco today'}, 'id': 'call_78771907f6674782af4f5044e957ac02'}])]), 'Weather Today in San Francisco, CA ; High / Low. 67°/54° ; Wind. 15 mph ; Humidity. 74% ; Dew Point. 58° ; Pressure. 29.90 in.')], 'agent_scratchpad': [AIMessage(content='', id='run-3bed1068-87ca-4c71-950a-96cea2fc0587-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'weather in San Francisco today'}, 'id': 'call_78771907f6674782af4f5044e957ac02'}]), ToolMessage(content='Weather Today in San Francisco, CA ; High / Low. 67°/54° ; Wind. 15 mph ; Humidity. 74% ; Dew Point. 58° ; Pressure. 29.90 in.', name='google_search', tool_call_id='call_78771907f6674782af4f5044e957ac02')]}
# Fake function| Prompt: messages=[SystemMessage(content='You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n'), HumanMessage(content='Find todays weather in san francisco?'), AIMessage(content='', id='run-3bed1068-87ca-4c71-950a-96cea2fc0587-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'weather in San Francisco today'}, 'id': 'call_78771907f6674782af4f5044e957ac02'}]), ToolMessage(content='Weather Today in San Francisco, CA ; High / Low. 67°/54° ; Wind. 15 mph ; Humidity. 74% ; Dew Point. 58° ; Pressure. 29.90 in.', name='google_search', tool_call_id='call_78771907f6674782af4f5044e957ac02')]
# ENTERED CUSTOM OLLAMA FUNCTIONS GENERATE
# kwargs: {}
# Ollama messages: [{'role': 'system', 'content': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'images': []}, {'role': 'user', 'content': 'Find todays weather in san francisco?', 'images': []}, {'role': 'assistant', 'content': '', 'images': []}, {'role': 'user', 'content': 'Analyse this response taken from External tool google_search to answer my query: Weather Today in San Francisco, CA ; High / Low. 67°/54° ; Wind. 15 mph ; Humidity. 74% ; Dew Point. 58° ; Pressure. 29.90 in.', 'images': []}]
# final_chunk:  text='{\n  "tool": "google_search",\n  "tool_input": {\n    "query": "Weather Today in San Francisco, CA"\n  }\n}' generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T02:42:54.295948Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 2447426792, 'load_duration': 12590833, 'prompt_eval_count': 72, 'prompt_eval_duration': 654584000, 'eval_count': 32, 'eval_duration': 1762362000} message=AIMessageChunk(content='{\n  "tool": "google_search",\n  "tool_input": {\n    "query": "Weather Today in San Francisco, CA"\n  }\n}') Chunk text:  {
#   "tool": "google_search",
#   "tool_input": {
#     "query": "Weather Today in San Francisco, CA"
#   }
# }
# EXECUTION DONE: generations=[ChatGeneration(text='{\n  "tool": "google_search",\n  "tool_input": {\n    "query": "Weather Today in San Francisco, CA"\n  }\n}', generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T02:42:54.295948Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 2447426792, 'load_duration': 12590833, 'prompt_eval_count': 72, 'prompt_eval_duration': 654584000, 'eval_count': 32, 'eval_duration': 1762362000}, message=AIMessage(content='{\n  "tool": "google_search",\n  "tool_input": {\n    "query": "Weather Today in San Francisco, CA"\n  }\n}'))] llm_output=None
# Response: Ollama:  {'tool': 'google_search', 'tool_input': {'query': 'Weather Today in San Francisco, CA'}}
# response message with func: content='' tool_calls=[{'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_62b6ee62302341c4ad9dcecc46fa1b50'}]
# Result from Ollm before extracting:  [ChatGeneration(message=AIMessage(content='', id='run-9e607be4-dbc4-4f96-bcf7-cd75ed7f7a9c-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_62b6ee62302341c4ad9dcecc46fa1b50'}]))]
# Ollama func parse result:  content='' id='run-9e607be4-dbc4-4f96-bcf7-cd75ed7f7a9c-0' tool_calls=[{'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_62b6ee62302341c4ad9dcecc46fa1b50'}]
# Tool Call:  {'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_62b6ee62302341c4ad9dcecc46fa1b50'}
# Agent Outcome:  tool='google_search' tool_input={'query': 'Weather Today in San Francisco, CA'} log="\nInvoking: `google_search` with `{'query': 'Weather Today in San Francisco, CA'}`\n\n\n" message_log=[AIMessage(content='', id='run-9e607be4-dbc4-4f96-bcf7-cd75ed7f7a9c-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_62b6ee62302341c4ad9dcecc46fa1b50'}])]
# keys in run continue: dict_keys(['agent_outcome', 'input', 'system_message', 'chat_history', 'intermediate_steps']), 1
# {'agent_outcome': AgentActionMessageLog(tool='google_search', tool_input={'query': 'Weather Today in San Francisco, CA'}, log="\nInvoking: `google_search` with `{'query': 'Weather Today in San Francisco, CA'}`\n\n\n", message_log=[AIMessage(content='', id='run-9e607be4-dbc4-4f96-bcf7-cd75ed7f7a9c-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_62b6ee62302341c4ad9dcecc46fa1b50'}])])}
# ----
# keys in run tools: dict_keys(['input', 'system_message', 'chat_history', 'agent_outcome', 'intermediate_steps']), 1
# {'intermediate_steps': [(AgentActionMessageLog(tool='google_search', tool_input={'query': 'Weather Today in San Francisco, CA'}, log="\nInvoking: `google_search` with `{'query': 'Weather Today in San Francisco, CA'}`\n\n\n", message_log=[AIMessage(content='', id='run-9e607be4-dbc4-4f96-bcf7-cd75ed7f7a9c-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_62b6ee62302341c4ad9dcecc46fa1b50'}])]), 'Mon 08 | Day ... Partly cloudy. High around 65F. Winds WSW at 10 to 20 mph.')]}
# ----
# keys in run agent: dict_keys(['input', 'system_message', 'chat_history', 'agent_outcome', 'intermediate_steps'])
# Agent Action in create tool message func:  tool='google_search' tool_input={'query': 'weather in San Francisco today'} log="\nInvoking: `google_search` with `{'query': 'weather in San Francisco today'}`\n\n\n" message_log=[AIMessage(content='', id='run-3bed1068-87ca-4c71-950a-96cea2fc0587-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'weather in San Francisco today'}, 'id': 'call_78771907f6674782af4f5044e957ac02'}])]
# Agent Action in create tool message func:  tool='google_search' tool_input={'query': 'Weather Today in San Francisco, CA'} log="\nInvoking: `google_search` with `{'query': 'Weather Today in San Francisco, CA'}`\n\n\n" message_log=[AIMessage(content='', id='run-9e607be4-dbc4-4f96-bcf7-cd75ed7f7a9c-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_62b6ee62302341c4ad9dcecc46fa1b50'}])]
# Agent Input - Inside agent chain: {'input': 'Find todays weather in san francisco?', 'system_message': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'chat_history': [], 'agent_outcome': AgentActionMessageLog(tool='google_search', tool_input={'query': 'Weather Today in San Francisco, CA'}, log="\nInvoking: `google_search` with `{'query': 'Weather Today in San Francisco, CA'}`\n\n\n", message_log=[AIMessage(content='', id='run-9e607be4-dbc4-4f96-bcf7-cd75ed7f7a9c-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_62b6ee62302341c4ad9dcecc46fa1b50'}])]), 'intermediate_steps': [(AgentActionMessageLog(tool='google_search', tool_input={'query': 'weather in San Francisco today'}, log="\nInvoking: `google_search` with `{'query': 'weather in San Francisco today'}`\n\n\n", message_log=[AIMessage(content='', id='run-3bed1068-87ca-4c71-950a-96cea2fc0587-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'weather in San Francisco today'}, 'id': 'call_78771907f6674782af4f5044e957ac02'}])]), 'Weather Today in San Francisco, CA ; High / Low. 67°/54° ; Wind. 15 mph ; Humidity. 74% ; Dew Point. 58° ; Pressure. 29.90 in.'), (AgentActionMessageLog(tool='google_search', tool_input={'query': 'Weather Today in San Francisco, CA'}, log="\nInvoking: `google_search` with `{'query': 'Weather Today in San Francisco, CA'}`\n\n\n", message_log=[AIMessage(content='', id='run-9e607be4-dbc4-4f96-bcf7-cd75ed7f7a9c-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_62b6ee62302341c4ad9dcecc46fa1b50'}])]), 'Mon 08 | Day ... Partly cloudy. High around 65F. Winds WSW at 10 to 20 mph.')], 'agent_scratchpad': [AIMessage(content='', id='run-3bed1068-87ca-4c71-950a-96cea2fc0587-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'weather in San Francisco today'}, 'id': 'call_78771907f6674782af4f5044e957ac02'}]), ToolMessage(content='Weather Today in San Francisco, CA ; High / Low. 67°/54° ; Wind. 15 mph ; Humidity. 74% ; Dew Point. 58° ; Pressure. 29.90 in.', name='google_search', tool_call_id='call_78771907f6674782af4f5044e957ac02'), AIMessage(content='', id='run-9e607be4-dbc4-4f96-bcf7-cd75ed7f7a9c-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_62b6ee62302341c4ad9dcecc46fa1b50'}]), ToolMessage(content='Mon 08 | Day ... Partly cloudy. High around 65F. Winds WSW at ...
# Fake function| Prompt: messages=[SystemMessage(content='You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n'), HumanMessage(content='Find todays weather in san francisco?'), AIMessage(content='', id='run-3bed1068-87ca-4c71-950a-96cea2fc0587-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'weather in San Francisco today'}, 'id': 'call_78771907f6674782af4f5044e957ac02'}]), ToolMessage(content='Weather Today in San Francisco, CA ; High / Low. 67°/54° ; Wind. 15 mph ; Humidity. 74% ; Dew Point. 58° ; Pressure. 29.90 in.', name='google_search', tool_call_id='call_78771907f6674782af4f5044e957ac02'), AIMessage(content='', id='run-9e607be4-dbc4-4f96-bcf7-cd75ed7f7a9c-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_62b6ee62302341c4ad9dcecc46fa1b50'}]), ToolMessage(content='Mon 08 | Day ... Partly cloudy. High around 65F. Winds WSW at 10 to 20 mph.', name='google_search', tool_call_id='call_62b6ee62302341c4ad9dcecc46fa1b50')]
# ENTERED CUSTOM OLLAMA FUNCTIONS GENERATE
# kwargs: {}
# Ollama messages: [{'role': 'system', 'content': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'images': []}, {'role': 'user', 'content': 'Find todays weather in san francisco?', 'images': []}, {'role': 'assistant', 'content': '', 'images': []}, {'role': 'user', 'content': 'Analyse this response taken from External tool google_search to answer my query: Weather Today in San Francisco, CA ; High / Low. 67°/54° ; Wind. 15 mph ; Humidity. 74% ; Dew Point. 58° ; Pressure. 29.90 in.', 'images': []}, {'role': 'assistant', 'content': '', 'images': []}, {'role': 'user', 'content': 'Analyse this response taken from External tool google_search to answer my query: Mon 08 | Day ... Partly cloudy. High around 65F. Winds WSW at 10 to 20 mph.', 'images': []}]
# final_chunk:  text='{"tool": "google_search", "tool_input": {"query": "Weather Today in San Francisco, CA"}}' generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T02:42:57.01857Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 1803220583, 'load_duration': 5055125, 'prompt_eval_count': 52, 'prompt_eval_duration': 422523000, 'eval_count': 24, 'eval_duration': 1364736000} message=AIMessageChunk(content='{"tool": "google_search", "tool_input": {"query": "Weather Today in San Francisco, CA"}}') Chunk text:  {"tool": "google_search", "tool_input": {"query": "Weather Today in San Francisco, CA"}}
# EXECUTION DONE: generations=[ChatGeneration(text='{"tool": "google_search", "tool_input": {"query": "Weather Today in San Francisco, CA"}}', generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T02:42:57.01857Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 1803220583, 'load_duration': 5055125, 'prompt_eval_count': 52, 'prompt_eval_duration': 422523000, 'eval_count': 24, 'eval_duration': 1364736000}, message=AIMessage(content='{"tool": "google_search", "tool_input": {"query": "Weather Today in San Francisco, CA"}}'))] llm_output=None
# Response: Ollama:  {'tool': 'google_search', 'tool_input': {'query': 'Weather Today in San Francisco, CA'}}
# response message with func: content='' tool_calls=[{'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_52066b56eadd4be2ae592678141f7b4d'}]
# Result from Ollm before extracting:  [ChatGeneration(message=AIMessage(content='', id='run-92b2800f-b0ed-4ed5-9298-6bc48b870435-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_52066b56eadd4be2ae592678141f7b4d'}]))]
# Ollama func parse result:  content='' id='run-92b2800f-b0ed-4ed5-9298-6bc48b870435-0' tool_calls=[{'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_52066b56eadd4be2ae592678141f7b4d'}]
# Tool Call:  {'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_52066b56eadd4be2ae592678141f7b4d'}
# Agent Outcome:  tool='google_search' tool_input={'query': 'Weather Today in San Francisco, CA'} log="\nInvoking: `google_search` with `{'query': 'Weather Today in San Francisco, CA'}`\n\n\n" message_log=[AIMessage(content='', id='run-92b2800f-b0ed-4ed5-9298-6bc48b870435-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_52066b56eadd4be2ae592678141f7b4d'}])]
# keys in run continue: dict_keys(['agent_outcome', 'input', 'system_message', 'chat_history', 'intermediate_steps']), 2
# {'agent_outcome': AgentActionMessageLog(tool='google_search', tool_input={'query': 'Weather Today in San Francisco, CA'}, log="\nInvoking: `google_search` with `{'query': 'Weather Today in San Francisco, CA'}`\n\n\n", message_log=[AIMessage(content='', id='run-92b2800f-b0ed-4ed5-9298-6bc48b870435-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_52066b56eadd4be2ae592678141f7b4d'}])])}
# ----
# keys in run tools: dict_keys(['input', 'system_message', 'chat_history', 'agent_outcome', 'intermediate_steps']), 2
# {'intermediate_steps': [(AgentActionMessageLog(tool='google_search', tool_input={'query': 'Weather Today in San Francisco, CA'}, log="\nInvoking: `google_search` with `{'query': 'Weather Today in San Francisco, CA'}`\n\n\n", message_log=[AIMessage(content='', id='run-92b2800f-b0ed-4ed5-9298-6bc48b870435-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_52066b56eadd4be2ae592678141f7b4d'}])]), 'Mon 08 | Day ... Partly cloudy. High around 65F. Winds WSW at 10 to 20 mph.')]}
# ----
# keys in run agent: dict_keys(['input', 'system_message', 'chat_history', 'agent_outcome', 'intermediate_steps'])
# Agent Action in create tool message func:  tool='google_search' tool_input={'query': 'weather in San Francisco today'} log="\nInvoking: `google_search` with `{'query': 'weather in San Francisco today'}`\n\n\n" message_log=[AIMessage(content='', id='run-3bed1068-87ca-4c71-950a-96cea2fc0587-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'weather in San Francisco today'}, 'id': 'call_78771907f6674782af4f5044e957ac02'}])]
# Agent Action in create tool message func:  tool='google_search' tool_input={'query': 'Weather Today in San Francisco, CA'} log="\nInvoking: `google_search` with `{'query': 'Weather Today in San Francisco, CA'}`\n\n\n" message_log=[AIMessage(content='', id='run-9e607be4-dbc4-4f96-bcf7-cd75ed7f7a9c-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_62b6ee62302341c4ad9dcecc46fa1b50'}])]
# Agent Action in create tool message func:  tool='google_search' tool_input={'query': 'Weather Today in San Francisco, CA'} log="\nInvoking: `google_search` with `{'query': 'Weather Today in San Francisco, CA'}`\n\n\n" message_log=[AIMessage(content='', id='run-92b2800f-b0ed-4ed5-9298-6bc48b870435-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_52066b56eadd4be2ae592678141f7b4d'}])]
# Agent Input - Inside agent chain: {'input': 'Find todays weather in san francisco?', 'system_message': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'chat_history': [], 'agent_outcome': AgentActionMessageLog(tool='google_search', tool_input={'query': 'Weather Today in San Francisco, CA'}, log="\nInvoking: `google_search` with `{'query': 'Weather Today in San Francisco, CA'}`\n\n\n", message_log=[AIMessage(content='', id='run-92b2800f-b0ed-4ed5-9298-6bc48b870435-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_52066b56eadd4be2ae592678141f7b4d'}])]), 'intermediate_steps': [(AgentActionMessageLog(tool='google_search', tool_input={'query': 'weather in San Francisco today'}, log="\nInvoking: `google_search` with `{'query': 'weather in San Francisco today'}`\n\n\n", message_log=[AIMessage(content='', id='run-3bed1068-87ca-4c71-950a-96cea2fc0587-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'weather in San Francisco today'}, 'id': 'call_78771907f6674782af4f5044e957ac02'}])]), 'Weather Today in San Francisco, CA ; High / Low. 67°/54° ; Wind. 15 mph ; Humidity. 74% ; Dew Point. 58° ; Pressure. 29.90 in.'), (AgentActionMessageLog(tool='google_search', tool_input={'query': 'Weather Today in San Francisco, CA'}, log="\nInvoking: `google_search` with `{'query': 'Weather Today in San Francisco, CA'}`\n\n\n", message_log=[AIMessage(content='', id='run-9e607be4-dbc4-4f96-bcf7-cd75ed7f7a9c-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_62b6ee62302341c4ad9dcecc46fa1b50'}])]), 'Mon 08 | Day ... Partly cloudy. High around 65F. Winds WSW at 10 to 20 mph.'), (AgentActionMessageLog(tool='google_search', tool_input={'query': 'Weather Today in San Francisco, CA'}, log="\nInvoking: `google_search` with `{'query': 'Weather Today in San Francisco, CA'}`\n\n\n", message_log=[AIMessage(content='', id='run-92b2800f-b0ed-4ed5-9298-6bc48b870435-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_52066b56eadd4be2ae592678141f7b4d'}])]), 'Mon 08 | Day ... Partly cloudy. High around 65F. Winds WSW at 10 to 20 mph.')], 'agent_scratchpad': [AIMessage(content='', id='run-3bed1068-87ca-4c71-950a-96cea2fc0587-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'weather in San Francisco today'}, 'id': 'call_78771907f6674782af4f5044e957ac02'}]), ToolMessage(c ...
# Fake function| Prompt: messages=[SystemMessage(content='You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n'), HumanMessage(content='Find todays weather in san francisco?'), AIMessage(content='', id='run-3bed1068-87ca-4c71-950a-96cea2fc0587-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'weather in San Francisco today'}, 'id': 'call_78771907f6674782af4f5044e957ac02'}]), ToolMessage(content='Weather Today in San Francisco, CA ; High / Low. 67°/54° ; Wind. 15 mph ; Humidity. 74% ; Dew Point. 58° ; Pressure. 29.90 in.', name='google_search', tool_call_id='call_78771907f6674782af4f5044e957ac02'), AIMessage(content='', id='run-9e607be4-dbc4-4f96-bcf7-cd75ed7f7a9c-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_62b6ee62302341c4ad9dcecc46fa1b50'}]), ToolMessage(content='Mon 08 | Day ... Partly cloudy. High around 65F. Winds WSW at 10 to 20 mph.', name='google_search', tool_call_id='call_62b6ee62302341c4ad9dcecc46fa1b50'), AIMessage(content='', id='run-92b2800f-b0ed-4ed5-9298-6bc48b870435-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Weather Today in San Francisco, CA'}, 'id': 'call_52066b56eadd4be2ae592678141f7b4d'}]), ToolMessage(content='Mon 08 | Day ... Partly cloudy. High around 65F. Winds WSW at 10 to 20 mph.', name='google_search', tool_call_id='call_52066b56eadd4be2ae592678141f7b4d')]
# ENTERED CUSTOM OLLAMA FUNCTIONS GENERATE
# kwargs: {}
# Ollama messages: [{'role': 'system', 'content': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'images': []}, {'role': 'user', 'content': 'Find todays weather in san francisco?', 'images': []}, {'role': 'assistant', 'content': '', 'images': []}, {'role': 'user', 'content': 'Analyse this response taken from External tool google_search to answer my query: Weather Today in San Francisco, CA ; High / Low. 67°/54° ; Wind. 15 mph ; Humidity. 74% ; Dew Point. 58° ; Pressure. 29.90 in.', 'images': []}, {'role': 'assistant', 'content': '', 'images': []}, {'role': 'user', 'content': 'Analyse this response taken from External tool google_search to answer my query: Mon 08 | Day ... Partly cloudy. High around 65F. Winds WSW at 10 to 20 mph.', 'images': []}, {'role': 'assistant', 'content': '', 'images': []}, {'role': 'user', 'content': 'Analyse this response taken from External tool google_search to answer my query: Mon 08 | Day ... Partly cloudy. High around 65F. Winds WSW at 10 to 20 mph.', 'images': []}]
# final_chunk:  text='{"tool": "conversational_response", "tool_input": {"response": "Today\'s weather in San Francisco is partly cloudy with a high of around 65°F and winds blowing at 10-20 mph."}}' generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T02:43:00.545651Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 3022037000, 'load_duration': 3193292, 'prompt_eval_count': 52, 'prompt_eval_duration': 422017000, 'eval_count': 46, 'eval_duration': 2570192000} message=AIMessageChunk(content='{"tool": "conversational_response", "tool_input": {"response": "Today\'s weather in San Francisco is partly cloudy with a high of around 65°F and winds blowing at 10-20 mph."}}') Chunk text:  {"tool": "conversational_response", "tool_input": {"response": "Today's weather in San Francisco is partly cloudy with a high of around 65°F and winds blowing at 10-20 mph."}}
# EXECUTION DONE: generations=[ChatGeneration(text='{"tool": "conversational_response", "tool_input": {"response": "Today\'s weather in San Francisco is partly cloudy with a high of around 65°F and winds blowing at 10-20 mph."}}', generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T02:43:00.545651Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 3022037000, 'load_duration': 3193292, 'prompt_eval_count': 52, 'prompt_eval_duration': 422017000, 'eval_count': 46, 'eval_duration': 2570192000}, message=AIMessage(content='{"tool": "conversational_response", "tool_input": {"response": "Today\'s weather in San Francisco is partly cloudy with a high of around 65°F and winds blowing at 10-20 mph."}}'))] llm_output=None
# Response: Ollama:  {'tool': 'conversational_response', 'tool_input': {'response': "Today's weather in San Francisco is partly cloudy with a high of around 65°F and winds blowing at 10-20 mph."}}
# Result from Ollm before extracting:  [ChatGeneration(text="Today's weather in San Francisco is partly cloudy with a high of around 65°F and winds blowing at 10-20 mph.", message=AIMessage(content="Today's weather in San Francisco is partly cloudy with a high of around 65°F and winds blowing at 10-20 mph.", id='run-63a5ae85-78f4-4c2b-80cd-d64d202804c6-0'))]
# Ollama func parse result:  content="Today's weather in San Francisco is partly cloudy with a high of around 65°F and winds blowing at 10-20 mph." id='run-63a5ae85-78f4-4c2b-80cd-d64d202804c6-0'
# Agent Outcome:  return_values={'output': "Today's weather in San Francisco is partly cloudy with a high of around 65°F and winds blowing at 10-20 mph."} log='content="Today\'s weather in San Francisco is partly cloudy with a high of around 65°F and winds blowing at 10-20 mph." id=\'run-63a5ae85-78f4-4c2b-80cd-d64d202804c6-0\''
# keys in run continue: dict_keys(['agent_outcome', 'input', 'system_message', 'chat_history', 'intermediate_steps']), 3
# {'agent_outcome': AgentFinish(return_values={'output': "Today's weather in San Francisco is partly cloudy with a high of around 65°F and winds blowing at 10-20 mph."}, log='content="Today\'s weather in San Francisco is partly cloudy with a high of around 65°F and winds blowing at 10-20 mph." id=\'run-63a5ae85-78f4-4c2b-80cd-d64d202804c6-0\'')}
# ----

# %%
# Ollama - Llama3:8b + Google Search
# inputs = {"input": "what is the weather in sf", "chat_history": [], "system_message": str(system_message.content)}
# inputs = {"input": "what is machine learning in simple words?", "chat_history": [], "system_message": str(system_message.content)}
# inputs = {"input": "Find todays weather in san francisco?", "chat_history": [], "system_message": str(system_message.content)}
inputs = {"input": "Who is the current Prime Minister of Australia?", "chat_history": [], "system_message": str(system_message.content)}
for s in app.stream(inputs):
    print(list(s.values())[0])
    print("----")
# Out:
# keys in run agent: dict_keys(['input', 'system_message', 'chat_history', 'agent_outcome', 'intermediate_steps'])
# Agent Input - Inside agent chain: {'input': 'Who is the current Prime Minister of Australia?', 'system_message': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'chat_history': [], 'agent_outcome': None, 'intermediate_steps': [], 'agent_scratchpad': []}
# Fake function| Prompt: messages=[SystemMessage(content='You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n'), HumanMessage(content='Who is the current Prime Minister of Australia?')]
# ENTERED CUSTOM OLLAMA FUNCTIONS GENERATE
# kwargs: {}
# Ollama messages: [{'role': 'system', 'content': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'images': []}, {'role': 'user', 'content': 'Who is the current Prime Minister of Australia?', 'images': []}]
# final_chunk:  text='{\n  "tool": "google_search",\n  "tool_input": {\n    "query": "current Prime Minister of Australia"\n  }\n}' generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T02:41:25.995955Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 15061720459, 'load_duration': 11262520959, 'prompt_eval_count': 377, 'prompt_eval_duration': 2189614000, 'eval_count': 30, 'eval_duration': 1599378000} message=AIMessageChunk(content='{\n  "tool": "google_search",\n  "tool_input": {\n    "query": "current Prime Minister of Australia"\n  }\n}') Chunk text:  {
#   "tool": "google_search",
#   "tool_input": {
#     "query": "current Prime Minister of Australia"
#   }
# }
# EXECUTION DONE: generations=[ChatGeneration(text='{\n  "tool": "google_search",\n  "tool_input": {\n    "query": "current Prime Minister of Australia"\n  }\n}', generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T02:41:25.995955Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 15061720459, 'load_duration': 11262520959, 'prompt_eval_count': 377, 'prompt_eval_duration': 2189614000, 'eval_count': 30, 'eval_duration': 1599378000}, message=AIMessage(content='{\n  "tool": "google_search",\n  "tool_input": {\n    "query": "current Prime Minister of Australia"\n  }\n}'))] llm_output=None
# Response: Ollama:  {'tool': 'google_search', 'tool_input': {'query': 'current Prime Minister of Australia'}}
# response message with func: content='' tool_calls=[{'name': 'google_search', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_fcdbcda031fd45ee8f32c40bf3cd455d'}]
# Result from Ollm before extracting:  [ChatGeneration(message=AIMessage(content='', id='run-1df582f1-d2ee-474d-927c-d73e7f4b4388-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_fcdbcda031fd45ee8f32c40bf3cd455d'}]))]
# Ollama func parse result:  content='' id='run-1df582f1-d2ee-474d-927c-d73e7f4b4388-0' tool_calls=[{'name': 'google_search', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_fcdbcda031fd45ee8f32c40bf3cd455d'}]
# Tool Call:  {'name': 'google_search', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_fcdbcda031fd45ee8f32c40bf3cd455d'}
# Agent Outcome:  tool='google_search' tool_input={'query': 'current Prime Minister of Australia'} log="\nInvoking: `google_search` with `{'query': 'current Prime Minister of Australia'}`\n\n\n" message_log=[AIMessage(content='', id='run-1df582f1-d2ee-474d-927c-d73e7f4b4388-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_fcdbcda031fd45ee8f32c40bf3cd455d'}])]
# keys in run continue: dict_keys(['agent_outcome', 'input', 'system_message', 'chat_history', 'intermediate_steps']), 0
# {'agent_outcome': AgentActionMessageLog(tool='google_search', tool_input={'query': 'current Prime Minister of Australia'}, log="\nInvoking: `google_search` with `{'query': 'current Prime Minister of Australia'}`\n\n\n", message_log=[AIMessage(content='', id='run-1df582f1-d2ee-474d-927c-d73e7f4b4388-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_fcdbcda031fd45ee8f32c40bf3cd455d'}])])}
# ----
# keys in run tools: dict_keys(['input', 'system_message', 'chat_history', 'agent_outcome', 'intermediate_steps']), 0
# {'intermediate_steps': [(AgentActionMessageLog(tool='google_search', tool_input={'query': 'current Prime Minister of Australia'}, log="\nInvoking: `google_search` with `{'query': 'current Prime Minister of Australia'}`\n\n\n", message_log=[AIMessage(content='', id='run-1df582f1-d2ee-474d-927c-d73e7f4b4388-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_fcdbcda031fd45ee8f32c40bf3cd455d'}])]), 'Anthony Norman Albanese is an Australian politician serving as the 31st and current prime minister of Australia since 2022. He has been leader of the\xa0...')]}
# ----
# keys in run agent: dict_keys(['input', 'system_message', 'chat_history', 'agent_outcome', 'intermediate_steps'])
# Agent Action in create tool message func:  tool='google_search' tool_input={'query': 'current Prime Minister of Australia'} log="\nInvoking: `google_search` with `{'query': 'current Prime Minister of Australia'}`\n\n\n" message_log=[AIMessage(content='', id='run-1df582f1-d2ee-474d-927c-d73e7f4b4388-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_fcdbcda031fd45ee8f32c40bf3cd455d'}])]
# Agent Input - Inside agent chain: {'input': 'Who is the current Prime Minister of Australia?', 'system_message': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'chat_history': [], 'agent_outcome': AgentActionMessageLog(tool='google_search', tool_input={'query': 'current Prime Minister of Australia'}, log="\nInvoking: `google_search` with `{'query': 'current Prime Minister of Australia'}`\n\n\n", message_log=[AIMessage(content='', id='run-1df582f1-d2ee-474d-927c-d73e7f4b4388-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_fcdbcda031fd45ee8f32c40bf3cd455d'}])]), 'intermediate_steps': [(AgentActionMessageLog(tool='google_search', tool_input={'query': 'current Prime Minister of Australia'}, log="\nInvoking: `google_search` with `{'query': 'current Prime Minister of Australia'}`\n\n\n", message_log=[AIMessage(content='', id='run-1df582f1-d2ee-474d-927c-d73e7f4b4388-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_fcdbcda031fd45ee8f32c40bf3cd455d'}])]), 'Anthony Norman Albanese is an Australian politician serving as the 31st and current prime minister of Australia since 2022. He has been leader of the\xa0...')], 'agent_scratchpad': [AIMessage(content='', id='run-1df582f1-d2ee-474d-927c-d73e7f4b4388-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_fcdbcda031fd45ee8f32c40bf3cd455d'}]), ToolMessage(content='Anthony Norman Albanese is an Australian politician serving as the 31st and current prime minister of Australia since 2022. He has been leader of the\xa0...', name='google_search', tool_call_id='call_fcdbcda031fd45ee8f32c40bf3cd455d')]}
# Fake function| Prompt: messages=[SystemMessage(content='You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n'), HumanMessage(content='Who is the current Prime Minister of Australia?'), AIMessage(content='', id='run-1df582f1-d2ee-474d-927c-d73e7f4b4388-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_fcdbcda031fd45ee8f32c40bf3cd455d'}]), ToolMessage(content='Anthony Norman Albanese is an Australian politician serving as the 31st and current prime minister of Australia since 2022. He has been leader of the\xa0...', name='google_search', tool_call_id='call_fcdbcda031fd45ee8f32c40bf3cd455d')]
# ENTERED CUSTOM OLLAMA FUNCTIONS GENERATE
# kwargs: {}
# Ollama messages: [{'role': 'system', 'content': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "google_search",\n    "parameters": {\n      "title": "google_searchSchema",\n      "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\nArgs:\\n    query (str): Query to search on Google.\\n\\nReturns:\\n    str: Google search results.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "Search Google for recent results. For queries on recent topics/news/updates/weather/general_knowledge etc.\\n\\n    Args:\\n        query (str): Query to search on Google.\\n\\n    Returns:\\n        str: Google search results."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'images': []}, {'role': 'user', 'content': 'Who is the current Prime Minister of Australia?', 'images': []}, {'role': 'assistant', 'content': '', 'images': []}, {'role': 'user', 'content': 'Analyse this response taken from External tool google_search to answer my query: Anthony Norman Albanese is an Australian politician serving as the 31st and current prime minister of Australia since 2022. He has been leader of the\xa0...', 'images': []}]
# final_chunk:  text='{\n  "tool": "conversational_response",\n  "tool_input": {\n    "response": "Anthony Norman Albanese is the 31st and current Prime Minister of Australia, serving since 2022."\n  }\n}' generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T02:41:30.026626Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 3070738584, 'load_duration': 5426042, 'prompt_eval_count': 58, 'prompt_eval_duration': 421266000, 'eval_count': 48, 'eval_duration': 2637251000} message=AIMessageChunk(content='{\n  "tool": "conversational_response",\n  "tool_input": {\n    "response": "Anthony Norman Albanese is the 31st and current Prime Minister of Australia, serving since 2022."\n  }\n}') Chunk text:  {
#   "tool": "conversational_response",
#   "tool_input": {
#     "response": "Anthony Norman Albanese is the 31st and current Prime Minister of Australia, serving since 2022."
#   }
# }
# EXECUTION DONE: generations=[ChatGeneration(text='{\n  "tool": "conversational_response",\n  "tool_input": {\n    "response": "Anthony Norman Albanese is the 31st and current Prime Minister of Australia, serving since 2022."\n  }\n}', generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T02:41:30.026626Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 3070738584, 'load_duration': 5426042, 'prompt_eval_count': 58, 'prompt_eval_duration': 421266000, 'eval_count': 48, 'eval_duration': 2637251000}, message=AIMessage(content='{\n  "tool": "conversational_response",\n  "tool_input": {\n    "response": "Anthony Norman Albanese is the 31st and current Prime Minister of Australia, serving since 2022."\n  }\n}'))] llm_output=None
# Response: Ollama:  {'tool': 'conversational_response', 'tool_input': {'response': 'Anthony Norman Albanese is the 31st and current Prime Minister of Australia, serving since 2022.'}}
# Result from Ollm before extracting:  [ChatGeneration(text='Anthony Norman Albanese is the 31st and current Prime Minister of Australia, serving since 2022.', message=AIMessage(content='Anthony Norman Albanese is the 31st and current Prime Minister of Australia, serving since 2022.', id='run-5c7d925d-1aa8-43e6-b23a-96ff30df7140-0'))]
# Ollama func parse result:  content='Anthony Norman Albanese is the 31st and current Prime Minister of Australia, serving since 2022.' id='run-5c7d925d-1aa8-43e6-b23a-96ff30df7140-0'
# Agent Outcome:  return_values={'output': 'Anthony Norman Albanese is the 31st and current Prime Minister of Australia, serving since 2022.'} log="content='Anthony Norman Albanese is the 31st and current Prime Minister of Australia, serving since 2022.' id='run-5c7d925d-1aa8-43e6-b23a-96ff30df7140-0'"
# keys in run continue: dict_keys(['agent_outcome', 'input', 'system_message', 'chat_history', 'intermediate_steps']), 1
# {'agent_outcome': AgentFinish(return_values={'output': 'Anthony Norman Albanese is the 31st and current Prime Minister of Australia, serving since 2022.'}, log="content='Anthony Norman Albanese is the 31st and current Prime Minister of Australia, serving since 2022.' id='run-5c7d925d-1aa8-43e6-b23a-96ff30df7140-0'")}
# ----

# %%
# Ollama - Llama3:8b + TavilySearchResults
# inputs = {"input": "what is the weather in sf", "chat_history": [], "system_message": str(system_message.content)}
# inputs = {"input": "what is machine learning in simple words?", "chat_history": [], "system_message": str(system_message.content)}
# inputs = {"input": "Find todays weather in san francisco?", "chat_history": [], "system_message": str(system_message.content)}
inputs = {"input": "Who is the current Prime Minister of Australia?", "chat_history": [], "system_message": str(system_message.content)}
for s in app.stream(inputs):
    print(list(s.values())[0])
    print("----")
# Out:
# keys in run agent: dict_keys(['input', 'system_message', 'chat_history', 'agent_outcome', 'intermediate_steps'])
# Agent Input - Inside agent chain: {'input': 'Who is the current Prime Minister of Australia?', 'system_message': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "tavily_search_results_json",\n    "parameters": {\n      "title": "TavilyInput",\n      "description": "Input for the Tavily tool.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "description": "search query to look up",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "A search engine optimized for comprehensive, accurate, and trusted results. Useful for when you need to answer questions about current events. Input should be a search query."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'chat_history': [], 'agent_outcome': None, 'intermediate_steps': [], 'agent_scratchpad': []}
# Fake function| Prompt: messages=[SystemMessage(content='You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "tavily_search_results_json",\n    "parameters": {\n      "title": "TavilyInput",\n      "description": "Input for the Tavily tool.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "description": "search query to look up",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "A search engine optimized for comprehensive, accurate, and trusted results. Useful for when you need to answer questions about current events. Input should be a search query."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n'), HumanMessage(content='Who is the current Prime Minister of Australia?')]
# ENTERED CUSTOM OLLAMA FUNCTIONS GENERATE
# kwargs: {}
# Ollama messages: [{'role': 'system', 'content': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "tavily_search_results_json",\n    "parameters": {\n      "title": "TavilyInput",\n      "description": "Input for the Tavily tool.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "description": "search query to look up",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "A search engine optimized for comprehensive, accurate, and trusted results. Useful for when you need to answer questions about current events. Input should be a search query."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'images': []}, {'role': 'user', 'content': 'Who is the current Prime Minister of Australia?', 'images': []}]
# final_chunk:  text='{"tool": "tavily_search_results_json", "tool_input": {"query": "current Prime Minister of Australia"}}' generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T01:39:24.389495Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 7332866208, 'load_duration': 5611667, 'prompt_eval_count': 11, 'prompt_eval_duration': 5792586000, 'eval_count': 26, 'eval_duration': 1527030000} message=AIMessageChunk(content='{"tool": "tavily_search_results_json", "tool_input": {"query": "current Prime Minister of Australia"}}') Chunk text:  {"tool": "tavily_search_results_json", "tool_input": {"query": "current Prime Minister of Australia"}}
# EXECUTION DONE: generations=[ChatGeneration(text='{"tool": "tavily_search_results_json", "tool_input": {"query": "current Prime Minister of Australia"}}', generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T01:39:24.389495Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 7332866208, 'load_duration': 5611667, 'prompt_eval_count': 11, 'prompt_eval_duration': 5792586000, 'eval_count': 26, 'eval_duration': 1527030000}, message=AIMessage(content='{"tool": "tavily_search_results_json", "tool_input": {"query": "current Prime Minister of Australia"}}'))] llm_output=None
# Response: Ollama:  {'tool': 'tavily_search_results_json', 'tool_input': {'query': 'current Prime Minister of Australia'}}
# response message with func: content='' tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_6841f329a9a84c1fb85cf71d5e8fbf1e'}]
# Result from Ollm before extracting:  [ChatGeneration(message=AIMessage(content='', id='run-c70fcb90-626e-41ff-b41c-a437a7c87212-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_6841f329a9a84c1fb85cf71d5e8fbf1e'}]))]
# Ollama func parse result:  content='' id='run-c70fcb90-626e-41ff-b41c-a437a7c87212-0' tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_6841f329a9a84c1fb85cf71d5e8fbf1e'}]
# Tool Call:  {'name': 'tavily_search_results_json', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_6841f329a9a84c1fb85cf71d5e8fbf1e'}
# Agent Outcome:  tool='tavily_search_results_json' tool_input={'query': 'current Prime Minister of Australia'} log="\nInvoking: `tavily_search_results_json` with `{'query': 'current Prime Minister of Australia'}`\n\n\n" message_log=[AIMessage(content='', id='run-c70fcb90-626e-41ff-b41c-a437a7c87212-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_6841f329a9a84c1fb85cf71d5e8fbf1e'}])]
# keys in run continue: dict_keys(['agent_outcome', 'input', 'system_message', 'chat_history', 'intermediate_steps']), 0
# {'agent_outcome': AgentActionMessageLog(tool='tavily_search_results_json', tool_input={'query': 'current Prime Minister of Australia'}, log="\nInvoking: `tavily_search_results_json` with `{'query': 'current Prime Minister of Australia'}`\n\n\n", message_log=[AIMessage(content='', id='run-c70fcb90-626e-41ff-b41c-a437a7c87212-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_6841f329a9a84c1fb85cf71d5e8fbf1e'}])])}
# ----
# keys in run tools: dict_keys(['input', 'system_message', 'chat_history', 'agent_outcome', 'intermediate_steps']), 0
# {'intermediate_steps': [(AgentActionMessageLog(tool='tavily_search_results_json', tool_input={'query': 'current Prime Minister of Australia'}, log="\nInvoking: `tavily_search_results_json` with `{'query': 'current Prime Minister of Australia'}`\n\n\n", message_log=[AIMessage(content='', id='run-c70fcb90-626e-41ff-b41c-a437a7c87212-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_6841f329a9a84c1fb85cf71d5e8fbf1e'}])]), '[{\'url\': \'https://www.skynews.com.au/australia-news/we-want-him-home-prime-minister-anthony-albanese-highlights-diplomatic-efforts-in-julian-assanges-us-court-case/news-story/01633a75f10b2527edddc83aad3b6879\', \'content\': "Politics Defence & foreign affairs Coronavirus Crime Sport Weather United States United Kingdom China Global Affairs Andrew Bolt Chris Kenny Paul Murray Peta Credlin Rita Panahi Sharri Markson Outsiders Insights & analysis Finance Markets Media Real Estate Tech & innovation Energy Science Arts & Culture Celebrity Life Health Trending Live channels Opinion programs News shows Documentaries Sky News Radio The Bolt Report Business Now Business Weekend Credlin Erin The Kenny Report The Late Debate The Media Show Outsiders Paul Murray Live Power Hour The Rita Panahi Show Royal Report Sharri Steve Price The Sunday Showdown The U.S. Report Special Investigations ‘Positive outcome’: Prime Minister Anthony Albanese highlights diplomatic efforts in Julian Assange\'s US court case Prime Minister Anthony Albanese has stressed Australia’s ongoing diplomatic efforts for a “positive outcome” in the criminal trial of WikiLeaks founder Julian Assange.  He pointed to consular assistance provided to Assange and noted the presence of Australia’s High Commissioner to the UK Stephen Smith and US Ambassador Kevin Rudd at the trial.  The founder of WikiLeaks, Julian Assange, attended the US District Court in the Northern Mariana Islands on Wednesday, accompanied by Australian Ambassador to the US Kevin Rudd.  As the high-profile trial of Julian Assange took place in Saipan on Wednesday, Prime Minister Anthony Albanese revealed the diplomacy process had been “considered” and “calibrated”.  Register Join the conversation, you are commenting as Logout Our Apps"}]')]}
# ----
# keys in run agent: dict_keys(['input', 'system_message', 'chat_history', 'agent_outcome', 'intermediate_steps'])
# Agent Action in create tool message func:  tool='tavily_search_results_json' tool_input={'query': 'current Prime Minister of Australia'} log="\nInvoking: `tavily_search_results_json` with `{'query': 'current Prime Minister of Australia'}`\n\n\n" message_log=[AIMessage(content='', id='run-c70fcb90-626e-41ff-b41c-a437a7c87212-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_6841f329a9a84c1fb85cf71d5e8fbf1e'}])]
# Agent Input - Inside agent chain: {'input': 'Who is the current Prime Minister of Australia?', 'system_message': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "tavily_search_results_json",\n    "parameters": {\n      "title": "TavilyInput",\n      "description": "Input for the Tavily tool.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "description": "search query to look up",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "A search engine optimized for comprehensive, accurate, and trusted results. Useful for when you need to answer questions about current events. Input should be a search query."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'chat_history': [], 'agent_outcome': AgentActionMessageLog(tool='tavily_search_results_json', tool_input={'query': 'current Prime Minister of Australia'}, log="\nInvoking: `tavily_search_results_json` with `{'query': 'current Prime Minister of Australia'}`\n\n\n", message_log=[AIMessage(content='', id='run-c70fcb90-626e-41ff-b41c-a437a7c87212-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_6841f329a9a84c1fb85cf71d5e8fbf1e'}])]), 'intermediate_steps': [(AgentActionMessageLog(tool='tavily_search_results_json', tool_input={'query': 'current Prime Minister of Australia'}, log="\nInvoking: `tavily_search_results_json` with `{'query': 'current Prime Minister of Australia'}`\n\n\n", message_log=[AIMessage(content='', id='run-c70fcb90-626e-41ff-b41c-a437a7c87212-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_6841f329a9a84c1fb85cf71d5e8fbf1e'}])]), '[{\'url\': \'https://www.skynews.com.au/australia-news/we-want-him-home-prime-minister-anthony-albanese-highlights-diplomatic-efforts-in-julian-assanges-us-court-case/news-story/01633a75f10b2527edddc83aad3b6879\', \'content\': "Politics Defence & foreign affairs Coronavirus Crime Sport Weather United States United Kingdom China Global Affairs Andrew Bolt Chris Kenny Paul Murray Peta Credlin Rita Panahi Sharri Markson Outsiders Insights & analysis Finance Markets Media Real Estate Tech & innovation Energy Science Arts & Culture Celebrity Life Health Trending Live channels Opinion programs News shows Documentaries Sky News Radio The Bolt Report Business Now Business Weekend Credlin Erin The Kenny Report The Late Debate The Media Show Outsiders Paul Murray Live Power Hour The Rita Panahi Show Royal Report Sharri Steve Price The Sunday Showdown The U.S. Report Special Investigations ‘Positive outcome’: Prime Minister Anthony Albanese highlights diplomatic efforts in Julian Assange\'s US court case Prime Minister Anthony Albanese has stressed Australia’s ongoing diplomatic efforts for a “positive outcome” in the criminal trial of WikiLeaks founder Julian Assange.  He pointed to consular assistance provided to Assange and noted the presence of Australia’s High Commissioner to the UK Stephen Smith and US Ambassador Kevin Rudd at the trial.  The founder of WikiLeaks, Julian Assange, attended the US District Court in the Northern Mariana Islands on Wednesday,  ...
# Fake function| Prompt: messages=[SystemMessage(content='You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "tavily_search_results_json",\n    "parameters": {\n      "title": "TavilyInput",\n      "description": "Input for the Tavily tool.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "description": "search query to look up",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "A search engine optimized for comprehensive, accurate, and trusted results. Useful for when you need to answer questions about current events. Input should be a search query."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n'), HumanMessage(content='Who is the current Prime Minister of Australia?'), AIMessage(content='', id='run-c70fcb90-626e-41ff-b41c-a437a7c87212-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_6841f329a9a84c1fb85cf71d5e8fbf1e'}]), ToolMessage(content='[{\'url\': \'https://www.skynews.com.au/australia-news/we-want-him-home-prime-minister-anthony-albanese-highlights-diplomatic-efforts-in-julian-assanges-us-court-case/news-story/01633a75f10b2527edddc83aad3b6879\', \'content\': "Politics Defence & foreign affairs Coronavirus Crime Sport Weather United States United Kingdom China Global Affairs Andrew Bolt Chris Kenny Paul Murray Peta Credlin Rita Panahi Sharri Markson Outsiders Insights & analysis Finance Markets Media Real Estate Tech & innovation Energy Science Arts & Culture Celebrity Life Health Trending Live channels Opinion programs News shows Documentaries Sky News Radio The Bolt Report Business Now Business Weekend Credlin Erin The Kenny Report The Late Debate The Media Show Outsiders Paul Murray Live Power Hour The Rita Panahi Show Royal Report Sharri Steve Price The Sunday Showdown The U.S. Report Special Investigations ‘Positive outcome’: Prime Minister Anthony Albanese highlights diplomatic efforts in Julian Assange\'s US court case Prime Minister Anthony Albanese has stressed Australia’s ongoing diplomatic efforts for a “positive outcome” in the criminal trial of WikiLeaks founder Julian Assange.  He pointed to consular assistance provided to Assange and noted the presence of Australia’s High Commissioner to the UK Stephen Smith and US Ambassador Kevin Rudd at the trial.  The founder of WikiLeaks, Julian Assange, attended the US District Court in the Northern Mariana Islands on Wednesday, accompanied by Australian Ambassador to the US Kevin Rudd.  As the high-profile trial of Julian Assange took place in Saipan on Wednesday, Prime Minister Anthony Albanese revealed the diplomacy process had been “considered” and “calibrated”.  Register Join the conversation, you are commenting as Logout Our Apps"}]', name='tavily_search_results_json', tool_call_id='call_6841f329a9a84c1fb85cf71d5e8fbf1e')]
# ENTERED CUSTOM OLLAMA FUNCTIONS GENERATE
# kwargs: {}
# Ollama messages: [{'role': 'system', 'content': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "tavily_search_results_json",\n    "parameters": {\n      "title": "TavilyInput",\n      "description": "Input for the Tavily tool.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "description": "search query to look up",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "A search engine optimized for comprehensive, accurate, and trusted results. Useful for when you need to answer questions about current events. Input should be a search query."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'images': []}, {'role': 'user', 'content': 'Who is the current Prime Minister of Australia?', 'images': []}, {'role': 'assistant', 'content': '', 'images': []}, {'role': 'user', 'content': 'Analyse this response taken from External tool tavily_search_results_json to answer my query: [{\'url\': \'https://www.skynews.com.au/australia-news/we-want-him-home-prime-minister-anthony-albanese-highlights-diplomatic-efforts-in-julian-assanges-us-court-case/news-story/01633a75f10b2527edddc83aad3b6879\', \'content\': "Politics Defence & foreign affairs Coronavirus Crime Sport Weather United States United Kingdom China Global Affairs Andrew Bolt Chris Kenny Paul Murray Peta Credlin Rita Panahi Sharri Markson Outsiders Insights & analysis Finance Markets Media Real Estate Tech & innovation Energy Science Arts & Culture Celebrity Life Health Trending Live channels Opinion programs News shows Documentaries Sky News Radio The Bolt Report Business Now Business Weekend Credlin Erin The Kenny Report The Late Debate The Media Show Outsiders Paul Murray Live Power Hour The Rita Panahi Show Royal Report Sharri Steve Price The Sunday Showdown The U.S. Report Special Investigations ‘Positive outcome’: Prime Minister Anthony Albanese highlights diplomatic efforts in Julian Assange\'s US court case Prime Minister Anthony Albanese has stressed Australia’s ongoing diplomatic efforts for a “positive outcome” in the criminal trial of WikiLeaks founder Julian Assange.  He pointed to consular assistance provided to Assange and noted the presence of Australia’s High Commissioner to the UK Stephen Smith and US Ambassador Kevin Rudd at the trial.  The founder of WikiLeaks, Julian Assange, attended the US District Court in the Northern Mariana Islands on Wednesday, accompanied by Australian Ambassador to the US Kevin Rudd.  As the high-profile trial of Julian Assange took place in Saipan on Wednesday, Prime Minister Anthony Albanese revealed the diplomacy process had been “considered” and “calibrated”.  Register Join the conversation, you are commenting as Logout Our Apps"}]', 'images': []}]
# final_chunk:  text='{"tool": "tavily_search_results_json", "tool_input": {"query": "current Prime Minister of Australia"}}' generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T01:39:29.990944Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 4184085375, 'load_duration': 7936667, 'prompt_eval_count': 385, 'prompt_eval_duration': 2541794000, 'eval_count': 26, 'eval_duration': 1608477000} message=AIMessageChunk(content='{"tool": "tavily_search_results_json", "tool_input": {"query": "current Prime Minister of Australia"}}') Chunk text:  {"tool": "tavily_search_results_json", "tool_input": {"query": "current Prime Minister of Australia"}}
# EXECUTION DONE: generations=[ChatGeneration(text='{"tool": "tavily_search_results_json", "tool_input": {"query": "current Prime Minister of Australia"}}', generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T01:39:29.990944Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 4184085375, 'load_duration': 7936667, 'prompt_eval_count': 385, 'prompt_eval_duration': 2541794000, 'eval_count': 26, 'eval_duration': 1608477000}, message=AIMessage(content='{"tool": "tavily_search_results_json", "tool_input": {"query": "current Prime Minister of Australia"}}'))] llm_output=None
# Response: Ollama:  {'tool': 'tavily_search_results_json', 'tool_input': {'query': 'current Prime Minister of Australia'}}
# response message with func: content='' tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_168b6af2f4e84ff8a26a089a1f8514e7'}]
# Result from Ollm before extracting:  [ChatGeneration(message=AIMessage(content='', id='run-fff5ba72-e9b0-4b8c-9737-c94643aa205b-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_168b6af2f4e84ff8a26a089a1f8514e7'}]))]
# Ollama func parse result:  content='' id='run-fff5ba72-e9b0-4b8c-9737-c94643aa205b-0' tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_168b6af2f4e84ff8a26a089a1f8514e7'}]
# Tool Call:  {'name': 'tavily_search_results_json', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_168b6af2f4e84ff8a26a089a1f8514e7'}
# Agent Outcome:  tool='tavily_search_results_json' tool_input={'query': 'current Prime Minister of Australia'} log="\nInvoking: `tavily_search_results_json` with `{'query': 'current Prime Minister of Australia'}`\n\n\n" message_log=[AIMessage(content='', id='run-fff5ba72-e9b0-4b8c-9737-c94643aa205b-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_168b6af2f4e84ff8a26a089a1f8514e7'}])]
# keys in run continue: dict_keys(['agent_outcome', 'input', 'system_message', 'chat_history', 'intermediate_steps']), 1
# {'agent_outcome': AgentActionMessageLog(tool='tavily_search_results_json', tool_input={'query': 'current Prime Minister of Australia'}, log="\nInvoking: `tavily_search_results_json` with `{'query': 'current Prime Minister of Australia'}`\n\n\n", message_log=[AIMessage(content='', id='run-fff5ba72-e9b0-4b8c-9737-c94643aa205b-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_168b6af2f4e84ff8a26a089a1f8514e7'}])])}
# ----
# keys in run tools: dict_keys(['input', 'system_message', 'chat_history', 'agent_outcome', 'intermediate_steps']), 1
# {'intermediate_steps': [(AgentActionMessageLog(tool='tavily_search_results_json', tool_input={'query': 'current Prime Minister of Australia'}, log="\nInvoking: `tavily_search_results_json` with `{'query': 'current Prime Minister of Australia'}`\n\n\n", message_log=[AIMessage(content='', id='run-fff5ba72-e9b0-4b8c-9737-c94643aa205b-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_168b6af2f4e84ff8a26a089a1f8514e7'}])]), '[{\'url\': \'https://www.skynews.com.au/australia-news/we-want-him-home-prime-minister-anthony-albanese-highlights-diplomatic-efforts-in-julian-assanges-us-court-case/news-story/01633a75f10b2527edddc83aad3b6879\', \'content\': "Politics Defence & foreign affairs Coronavirus Crime Sport Weather United States United Kingdom China Global Affairs Andrew Bolt Chris Kenny Paul Murray Peta Credlin Rita Panahi Sharri Markson Outsiders Insights & analysis Finance Markets Media Real Estate Tech & innovation Energy Science Arts & Culture Celebrity Life Health Trending Live channels Opinion programs News shows Documentaries Sky News Radio The Bolt Report Business Now Business Weekend Credlin Erin The Kenny Report The Late Debate The Media Show Outsiders Paul Murray Live Power Hour The Rita Panahi Show Royal Report Sharri Steve Price The Sunday Showdown The U.S. Report Special Investigations ‘Positive outcome’: Prime Minister Anthony Albanese highlights diplomatic efforts in Julian Assange\'s US court case Prime Minister Anthony Albanese has stressed Australia’s ongoing diplomatic efforts for a “positive outcome” in the criminal trial of WikiLeaks founder Julian Assange.  He pointed to consular assistance provided to Assange and noted the presence of Australia’s High Commissioner to the UK Stephen Smith and US Ambassador Kevin Rudd at the trial.  The founder of WikiLeaks, Julian Assange, attended the US District Court in the Northern Mariana Islands on Wednesday, accompanied by Australian Ambassador to the US Kevin Rudd.  As the high-profile trial of Julian Assange took place in Saipan on Wednesday, Prime Minister Anthony Albanese revealed the diplomacy process had been “considered” and “calibrated”.  Register Join the conversation, you are commenting as Logout Our Apps"}]')]}
# ----
# keys in run agent: dict_keys(['input', 'system_message', 'chat_history', 'agent_outcome', 'intermediate_steps'])
# Agent Action in create tool message func:  tool='tavily_search_results_json' tool_input={'query': 'current Prime Minister of Australia'} log="\nInvoking: `tavily_search_results_json` with `{'query': 'current Prime Minister of Australia'}`\n\n\n" message_log=[AIMessage(content='', id='run-c70fcb90-626e-41ff-b41c-a437a7c87212-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_6841f329a9a84c1fb85cf71d5e8fbf1e'}])]
# Agent Action in create tool message func:  tool='tavily_search_results_json' tool_input={'query': 'current Prime Minister of Australia'} log="\nInvoking: `tavily_search_results_json` with `{'query': 'current Prime Minister of Australia'}`\n\n\n" message_log=[AIMessage(content='', id='run-fff5ba72-e9b0-4b8c-9737-c94643aa205b-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_168b6af2f4e84ff8a26a089a1f8514e7'}])]
# Agent Input - Inside agent chain: {'input': 'Who is the current Prime Minister of Australia?', 'system_message': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "tavily_search_results_json",\n    "parameters": {\n      "title": "TavilyInput",\n      "description": "Input for the Tavily tool.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "description": "search query to look up",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "A search engine optimized for comprehensive, accurate, and trusted results. Useful for when you need to answer questions about current events. Input should be a search query."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'chat_history': [], 'agent_outcome': AgentActionMessageLog(tool='tavily_search_results_json', tool_input={'query': 'current Prime Minister of Australia'}, log="\nInvoking: `tavily_search_results_json` with `{'query': 'current Prime Minister of Australia'}`\n\n\n", message_log=[AIMessage(content='', id='run-fff5ba72-e9b0-4b8c-9737-c94643aa205b-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_168b6af2f4e84ff8a26a089a1f8514e7'}])]), 'intermediate_steps': [(AgentActionMessageLog(tool='tavily_search_results_json', tool_input={'query': 'current Prime Minister of Australia'}, log="\nInvoking: `tavily_search_results_json` with `{'query': 'current Prime Minister of Australia'}`\n\n\n", message_log=[AIMessage(content='', id='run-c70fcb90-626e-41ff-b41c-a437a7c87212-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_6841f329a9a84c1fb85cf71d5e8fbf1e'}])]), '[{\'url\': \'https://www.skynews.com.au/australia-news/we-want-him-home-prime-minister-anthony-albanese-highlights-diplomatic-efforts-in-julian-assanges-us-court-case/news-story/01633a75f10b2527edddc83aad3b6879\', \'content\': "Politics Defence & foreign affairs Coronavirus Crime Sport Weather United States United Kingdom China Global Affairs Andrew Bolt Chris Kenny Paul Murray Peta Credlin Rita Panahi Sharri Markson Outsiders Insights & analysis Finance Markets Media Real Estate Tech & innovation Energy Science Arts & Culture Celebrity Life Health Trending Live channels Opinion programs News shows Documentaries Sky News Radio The Bolt Report Business Now Business Weekend Credlin Erin The Kenny Report The Late Debate The Media Show Outsiders Paul Murray Live Power Hour The Rita Panahi Show Royal Report Sharri Steve Price The Sunday Showdown The U.S. Report Special Investigations ‘Positive outcome’: Prime Minister Anthony Albanese highlights diplomatic efforts in Julian Assange\'s US court case Prime Minister Anthony Albanese has stressed Australia’s ongoing diplomatic efforts for a “positive outcome” in the criminal trial of WikiLeaks founder Julian Assange.  He pointed to consular assistance provided to Assange and noted the presence of Australia’s High Commissioner to the UK Stephen Smith and US Ambassador Kevin Rudd at the trial.  The founder of WikiLeaks, Julian Assange, attended the US District Court in the Northern Mariana Islands on Wednesday,  ...
# Fake function| Prompt: messages=[SystemMessage(content='You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "tavily_search_results_json",\n    "parameters": {\n      "title": "TavilyInput",\n      "description": "Input for the Tavily tool.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "description": "search query to look up",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "A search engine optimized for comprehensive, accurate, and trusted results. Useful for when you need to answer questions about current events. Input should be a search query."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n'), HumanMessage(content='Who is the current Prime Minister of Australia?'), AIMessage(content='', id='run-c70fcb90-626e-41ff-b41c-a437a7c87212-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_6841f329a9a84c1fb85cf71d5e8fbf1e'}]), ToolMessage(content='[{\'url\': \'https://www.skynews.com.au/australia-news/we-want-him-home-prime-minister-anthony-albanese-highlights-diplomatic-efforts-in-julian-assanges-us-court-case/news-story/01633a75f10b2527edddc83aad3b6879\', \'content\': "Politics Defence & foreign affairs Coronavirus Crime Sport Weather United States United Kingdom China Global Affairs Andrew Bolt Chris Kenny Paul Murray Peta Credlin Rita Panahi Sharri Markson Outsiders Insights & analysis Finance Markets Media Real Estate Tech & innovation Energy Science Arts & Culture Celebrity Life Health Trending Live channels Opinion programs News shows Documentaries Sky News Radio The Bolt Report Business Now Business Weekend Credlin Erin The Kenny Report The Late Debate The Media Show Outsiders Paul Murray Live Power Hour The Rita Panahi Show Royal Report Sharri Steve Price The Sunday Showdown The U.S. Report Special Investigations ‘Positive outcome’: Prime Minister Anthony Albanese highlights diplomatic efforts in Julian Assange\'s US court case Prime Minister Anthony Albanese has stressed Australia’s ongoing diplomatic efforts for a “positive outcome” in the criminal trial of WikiLeaks founder Julian Assange.  He pointed to consular assistance provided to Assange and noted the presence of Australia’s High Commissioner to the UK Stephen Smith and US Ambassador Kevin Rudd at the trial.  The founder of WikiLeaks, Julian Assange, attended the US District Court in the Northern Mariana Islands on Wednesday, accompanied by Australian Ambassador to the US Kevin Rudd.  As the high-profile trial of Julian Assange took place in Saipan on Wednesday, Prime Minister Anthony Albanese revealed the diplomacy process had been “considered” and “calibrated”.  Register Join the conversation, you are commenting as Logout Our Apps"}]', name='tavily_search_results_json', tool_call_id='call_6841f329a9a84c1fb85cf71d5e8fbf1e'), AIMessage(content='', id='run-fff5ba72-e9b0-4b8c-9737-c94643aa205b-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current Prime Minister of Australia'}, 'id': 'call_168b6af2f4e84ff8a26a089a1f8514e7'}]), ToolMessage(content='[{\'url\': \'https://www.skynews.com.au/australia-news/we-want-him-home-prime-mini ...
# ENTERED CUSTOM OLLAMA FUNCTIONS GENERATE
# kwargs: {}
# Ollama messages: [{'role': 'system', 'content': 'You are a helpful assistant. You have access to the following tools:\n\n[\n  {\n    "name": "tavily_search_results_json",\n    "parameters": {\n      "title": "TavilyInput",\n      "description": "Input for the Tavily tool.",\n      "type": "object",\n      "properties": {\n        "query": {\n          "title": "Query",\n          "description": "search query to look up",\n          "type": "string"\n        }\n      },\n      "required": [\n        "query"\n      ]\n    },\n    "description": "A search engine optimized for comprehensive, accurate, and trusted results. Useful for when you need to answer questions about current events. Input should be a search query."\n  },\n  {\n    "name": "conversational_response",\n    "description": "Respond conversationally if no other tools should be called for a given query.",\n    "parameters": {\n      "type": "object",\n      "properties": {\n        "response": {\n          "type": "string",\n          "description": "Conversational response to the user."\n        }\n      },\n      "required": [\n        "response"\n      ]\n    }\n  }\n]\n\nYou must always select one of the above tools and respond with only a JSON object matching the following schema if any external tool is required for the query:\n\n{\n  "tool": <name of the selected tool>,\n  "tool_input": <parameters for the selected tool, matching the tool\'s JSON schema>\n}\n', 'images': []}, {'role': 'user', 'content': 'Who is the current Prime Minister of Australia?', 'images': []}, {'role': 'assistant', 'content': '', 'images': []}, {'role': 'user', 'content': 'Analyse this response taken from External tool tavily_search_results_json to answer my query: [{\'url\': \'https://www.skynews.com.au/australia-news/we-want-him-home-prime-minister-anthony-albanese-highlights-diplomatic-efforts-in-julian-assanges-us-court-case/news-story/01633a75f10b2527edddc83aad3b6879\', \'content\': "Politics Defence & foreign affairs Coronavirus Crime Sport Weather United States United Kingdom China Global Affairs Andrew Bolt Chris Kenny Paul Murray Peta Credlin Rita Panahi Sharri Markson Outsiders Insights & analysis Finance Markets Media Real Estate Tech & innovation Energy Science Arts & Culture Celebrity Life Health Trending Live channels Opinion programs News shows Documentaries Sky News Radio The Bolt Report Business Now Business Weekend Credlin Erin The Kenny Report The Late Debate The Media Show Outsiders Paul Murray Live Power Hour The Rita Panahi Show Royal Report Sharri Steve Price The Sunday Showdown The U.S. Report Special Investigations ‘Positive outcome’: Prime Minister Anthony Albanese highlights diplomatic efforts in Julian Assange\'s US court case Prime Minister Anthony Albanese has stressed Australia’s ongoing diplomatic efforts for a “positive outcome” in the criminal trial of WikiLeaks founder Julian Assange.  He pointed to consular assistance provided to Assange and noted the presence of Australia’s High Commissioner to the UK Stephen Smith and US Ambassador Kevin Rudd at the trial.  The founder of WikiLeaks, Julian Assange, attended the US District Court in the Northern Mariana Islands on Wednesday, accompanied by Australian Ambassador to the US Kevin Rudd.  As the high-profile trial of Julian Assange took place in Saipan on Wednesday, Prime Minister Anthony Albanese revealed the diplomacy process had been “considered” and “calibrated”.  Register Join the conversation, you are commenting as Logout Our Apps"}]', 'images': []}, {'role': 'assistant', 'content': '', 'images': []}, {'role': 'user', 'content': 'Analyse this response taken from External tool tavily_search_results_json to answer my query: [{\'url\': \'https://www.skynews.com.au/australia-news/we-want-him-home-prime-minister-anthony-albanese-highlights-diplomatic-efforts-in-julian-assanges-us-court-case/news-story/01633a75f10b2527edddc83aad3b6879\', \'content\': "Politics Defence & foreign affairs Coronavirus Crime  ...
# final_chunk:  text='{ "tool": "conversational_response", "response": "The current Prime Minister of Australia is Anthony Albanese." }' generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T01:39:35.787461Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 4210523709, 'load_duration': 10267709, 'prompt_eval_count': 385, 'prompt_eval_duration': 2581224000, 'eval_count': 27, 'eval_duration': 1605248000} message=AIMessageChunk(content='{ "tool": "conversational_response", "response": "The current Prime Minister of Australia is Anthony Albanese." }') Chunk text:  { "tool": "conversational_response", "response": "The current Prime Minister of Australia is Anthony Albanese." }
# EXECUTION DONE: generations=[ChatGeneration(text='{ "tool": "conversational_response", "response": "The current Prime Minister of Australia is Anthony Albanese." }', generation_info={'model': 'llama3:8b', 'created_at': '2024-07-09T01:39:35.787461Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 4210523709, 'load_duration': 10267709, 'prompt_eval_count': 385, 'prompt_eval_duration': 2581224000, 'eval_count': 27, 'eval_duration': 1605248000}, message=AIMessage(content='{ "tool": "conversational_response", "response": "The current Prime Minister of Australia is Anthony Albanese." }'))] llm_output=None
# Response: Ollama:  {'tool': 'conversational_response', 'response': 'The current Prime Minister of Australia is Anthony Albanese.'}
# Result from Ollm before extracting:  [ChatGeneration(text='The current Prime Minister of Australia is Anthony Albanese.', message=AIMessage(content='The current Prime Minister of Australia is Anthony Albanese.', id='run-cabda566-aadf-4da3-8ede-f5fbf4a3fd1a-0'))]
# Ollama func parse result:  content='The current Prime Minister of Australia is Anthony Albanese.' id='run-cabda566-aadf-4da3-8ede-f5fbf4a3fd1a-0'
# Agent Outcome:  return_values={'output': 'The current Prime Minister of Australia is Anthony Albanese.'} log="content='The current Prime Minister of Australia is Anthony Albanese.' id='run-cabda566-aadf-4da3-8ede-f5fbf4a3fd1a-0'"
# keys in run continue: dict_keys(['agent_outcome', 'input', 'system_message', 'chat_history', 'intermediate_steps']), 2
# {'agent_outcome': AgentFinish(return_values={'output': 'The current Prime Minister of Australia is Anthony Albanese.'}, log="content='The current Prime Minister of Australia is Anthony Albanese.' id='run-cabda566-aadf-4da3-8ede-f5fbf4a3fd1a-0'")}
# ----
